# %% [markdown]
# # Project Individual assignment 1
#
# In this report, we will look into NVIDIA stock prices. We have two datasets, data about the stock movement, and a dataset containing news articles. The goal of the assignment is to use the news articles in order to predict the stock movement. We will use NLP methods to process the news article into more interpretable variables which can be used to predict the stock movement.
#
# The knowledge that we gained from lecture 2 and 3 will be used for this assignment. In lecture 2 we covered dataset filtering, preprocessing and analysis. While in lecture 3 we covered vector representation, Machine learning model and prediction.

# %% [markdown]
# ## Importing of packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re
import nltk
from collections import defaultdict
import datetime

import random

# %% [markdown]
# ## Importing of data

# %%
stock_data = pd.read_csv("data/NVDA.csv")
news_articles_data = pd.read_csv("data/us_equities_news_dataset.csv")

# %%
#news_articles_data = news_articles_data.sample(frac=0.01)
news_articles_data = news_articles_data

# %% [markdown]
# # EDA

# %%
stock_data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1999-01-25  0.044271  0.045833  0.041016  0.045313   0.041562  510480000
# 1  1999-01-26  0.045833  0.046745  0.041146  0.041797   0.038337  343200000
# 2  1999-01-27  0.041927  0.042969  0.039583  0.041667   0.038218  244368000
# 3  1999-01-28  0.041667  0.041927  0.041276  0.041536   0.038098  227520000
# 4  1999-01-29  0.041536  0.041667  0.039583  0.039583   0.036307  244032000

# %%
news_articles_data
# Out:
#             id ticker                                              title  \
# 0       221515    NIO  Why Shares of Chinese Electric Car Maker NIO A...
# 1       221516    NIO  NIO only consumer gainer  Workhorse Group amon...
# 2       221517    NIO  NIO leads consumer gainers  Beyond Meat and Ma...
# 3       221518    NIO                  NIO  NVAX among premarket gainers
# 4       221519    NIO                  PLUG  NIO among premarket gainers
# ...        ...    ...                                                ...
# 221508  443024      T                     Crude And Steel Still In Sync
# 221509  443025      T  Forget AT T  This Is The Telecom Stock You Sho...
# 221510  443026      T  Wall Street Exposed   Part 3   How Dividends C...
# 221511  443027      T       Weighing The Week Ahead  It s All About Jobs
# 221512  443028      T  Leap Wireless  LEAP    JPM Note and AT T   T M...
#
#        category                                            content  \
# 0          news  What s happening\nShares of Chinese electric c...
# 1          news  Gainers  NIO  NYSE NIO   7  \nLosers  MGP Ingr...
# 2          news  Gainers  NIO  NYSE NIO   14   Village Farms In...
# 3          news  Cemtrex  NASDAQ CETX   85  after FY results \n...
# 4          news  aTyr Pharma  NASDAQ LIFE   63  on Kyorin Pharm...
# ...         ...                                                ...
# 221508  opinion  We have been reporting on the trade off betwee...
# 221509  opinion  It s the largest cell phone provider in the wo...
# 221510  opinion  Before we dicuss how the mechanism of dividend...
# 221511  opinion  From start to finish  the coming week will hav...
# 221512  opinion  Leap Wireless International  Inc   Leap  is a ...
#
#        release_date         provider  \
# 0        2020-01-15  The Motley Fool
# 1        2020-01-18    Seeking Alpha
# 2        2020-01-15    Seeking Alpha
# 3        2020-01-15    Seeking Alpha
# 4        2020-01-06    Seeking Alpha
# ...             ...              ...
# 221508   2012-10-04       Ivan Kitov
# 221509   2012-05-30  StreetAuthority
# 221510   2012-07-16   Portfolio Cafe
# 221511   2012-09-02      Jeff Miller
# 221512   2011-12-31   Ophir Gottlieb
#
#                                                       url  article_id
# 0                                  https://invst.ly/pigqi     2060327
# 1                                  https://invst.ly/pje9c     2062196
# 2                                  https://invst.ly/pifmv     2060249
# 3                                  https://invst.ly/picu8     2060039
# 4       https://seekingalpha.com/news/3529772-plug-nio...     2053096
# ...                                                   ...         ...
# 221508  https://www.investing.com/analysis/crude-and-s...      138733
# 221509  https://www.investing.com/analysis/forget-at-t...      124829
# 221510  https://www.investing.com/analysis/wall-street...      129651
# 221511  https://www.investing.com/analysis/weighing-th...      134926
# 221512  https://www.investing.com/analysis/leap-wirele...      110079
#
# [221513 rows x 9 columns]

# %% [markdown]
# # Filtering of the articles that relate to NVIDIA

# %%
def insert_empty_column_to_df(df, original_column, extension):
    column_index = df.columns.get_loc(original_column)
    nr_word_column_name = f"{original_column}_{extension}"
    if not nr_word_column_name in df.columns:
        df.insert(loc=column_index+1, column=nr_word_column_name, value=0)
    return nr_word_column_name

# Check if nvda is in the text
def check_article_NVIDA_keyword_match(text, key_words = "nvidia|nvda"):
    try:
        if re.search(key_words, text.lower()):
            return True
        else:
            return False
    except AttributeError:
        print(text)
        return False
        
    
def add_nvidia_topic_title_content(df):
    """
    
    :param df: df to process
    :param column_name_to_count: the column name to count the nr of words present
    :return: 
    """
    title_column_name = insert_empty_column_to_df(df=df,
                                                     original_column="title",
                                                     extension="NVIDIA_topic")
    content_column_name = insert_empty_column_to_df(df=df,
                                                     original_column="content",
                                                     extension="NVIDIA_topic")
    
    
    
    for index, row in df.iterrows():
        df.at[index, title_column_name] = check_article_NVIDA_keyword_match(row["title"])
        df.at[index, content_column_name] = check_article_NVIDA_keyword_match(row["content"])

add_nvidia_topic_title_content(news_articles_data)
news_articles_data
# Out:
# /var/folders/f3/ykt1vfz96xz48try_trwdn440000gn/T/ipykernel_57538/2146164716.py:37: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, title_column_name] = check_article_NVIDA_keyword_match(row["title"])
# /var/folders/f3/ykt1vfz96xz48try_trwdn440000gn/T/ipykernel_57538/2146164716.py:38: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, content_column_name] = check_article_NVIDA_keyword_match(row["content"])
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#             id ticker                                              title  \
# 0       221515    NIO  Why Shares of Chinese Electric Car Maker NIO A...
# 1       221516    NIO  NIO only consumer gainer  Workhorse Group amon...
# 2       221517    NIO  NIO leads consumer gainers  Beyond Meat and Ma...
# 3       221518    NIO                  NIO  NVAX among premarket gainers
# 4       221519    NIO                  PLUG  NIO among premarket gainers
# ...        ...    ...                                                ...
# 221508  443024      T                     Crude And Steel Still In Sync
# 221509  443025      T  Forget AT T  This Is The Telecom Stock You Sho...
# 221510  443026      T  Wall Street Exposed   Part 3   How Dividends C...
# 221511  443027      T       Weighing The Week Ahead  It s All About Jobs
# 221512  443028      T  Leap Wireless  LEAP    JPM Note and AT T   T M...
#
#        title_NVIDIA_topic category  \
# 0                   False     news
# 1                   False     news
# 2                   False     news
# 3                   False     news
# 4                   False     news
# ...                   ...      ...
# 221508              False  opinion
# 221509              False  opinion
# 221510              False  opinion
# 221511              False  opinion
# 221512              False  opinion
#
#                                                   content  \
# 0       What s happening\nShares of Chinese electric c...
# 1       Gainers  NIO  NYSE NIO   7  \nLosers  MGP Ingr...
# 2       Gainers  NIO  NYSE NIO   14   Village Farms In...
# 3       Cemtrex  NASDAQ CETX   85  after FY results \n...
# 4       aTyr Pharma  NASDAQ LIFE   63  on Kyorin Pharm...
# ...                                                   ...
# 221508  We have been reporting on the trade off betwee...
# 221509  It s the largest cell phone provider in the wo...
# 221510  Before we dicuss how the mechanism of dividend...
# 221511  From start to finish  the coming week will hav...
# 221512  Leap Wireless International  Inc   Leap  is a ...
#
#        content_NVIDIA_topic release_date         provider  \
# 0                     False   2020-01-15  The Motley Fool
# 1                     False   2020-01-18    Seeking Alpha
# 2                     False   2020-01-15    Seeking Alpha
# 3                     False   2020-01-15    Seeking Alpha
# 4                     False   2020-01-06    Seeking Alpha
# ...                     ...          ...              ...
# 221508                False   2012-10-04       Ivan Kitov
# 221509                False   2012-05-30  StreetAuthority
# 221510                False   2012-07-16   Portfolio Cafe
# 221511                False   2012-09-02      Jeff Miller
# 221512                False   2011-12-31   Ophir Gottlieb
#
#                                                       url  article_id
# 0                                  https://invst.ly/pigqi     2060327
# 1                                  https://invst.ly/pje9c     2062196
# 2                                  https://invst.ly/pifmv     2060249
# 3                                  https://invst.ly/picu8     2060039
# 4       https://seekingalpha.com/news/3529772-plug-nio...     2053096
# ...                                                   ...         ...
# 221508  https://www.investing.com/analysis/crude-and-s...      138733
# 221509  https://www.investing.com/analysis/forget-at-t...      124829
# 221510  https://www.investing.com/analysis/wall-street...      129651
# 221511  https://www.investing.com/analysis/weighing-th...      134926
# 221512  https://www.investing.com/analysis/leap-wirele...      110079
#
# [221513 rows x 11 columns]

# %% [markdown]
# ### Interesting to note that there are 595 articles with NVIDA as a keyword but do not have the correct ticker

# %%
news_articles_data[(news_articles_data['ticker'] != "NVDA") & (news_articles_data['title_NVIDIA_topic'] == True)]
# Out:
#             id ticker                                              title  \
# 78      221593   UBER  The Zacks Analyst Blog Highlights  Advanced Mi...
# 187     221702   UBER  The Zacks Analyst Blog Highlights  Toyota Moto...
# 196     221711   UBER  NVIDIA  Greenbrier  Uber  Amazon And Apple Hig...
# 665     222180   UBER  The Zacks Analyst Blog Highlights  Alphabet  T...
# 691     222206   UBER  NVIDIA Pushes Self Drive Efforts  Must INTC  Q...
# ...        ...    ...                                                ...
# 221049  442565    AMD  Nvidia  NVDA  Hits All Time High After Strong ...
# 221052  442568    AMD  The Zacks Analyst Blog Highlights  Nvidia  AMD...
# 221105  442621    AMD  Double Top In NVIDIA  Time To Short Sell Semic...
# 221141  442657    AMD    Here s Why Nvidia  NVDA  Stock Is Gaining Today
# 221468  442984      T  Zacks com Featured Highlights  AT T  Nu Skin E...
#
#        title_NVIDIA_topic category  \
# 78                   True  opinion
# 187                  True  opinion
# 196                  True  opinion
# 665                  True  opinion
# 691                  True  opinion
# ...                   ...      ...
# 221049               True  opinion
# 221052               True  opinion
# 221105               True  opinion
# 221141               True  opinion
# 221468               True  opinion
#
#                                                   content  \
# 78      For Immediate ReleaseChicago  IL   January 13 ...
# 187     For Immediate ReleaseChicago  IL   December 3 ...
# 196     For Immediate ReleaseChicago  IL   November 26...
# 665     For Immediate Release\nChicago  IL   June 21  ...
# 691     NVIDIA Corporation s   NASDAQ NVDA   latest co...
# ...                                                   ...
# 221049  During the first trading period after AMD s   ...
# 221052  For Immediate ReleaseChicago  IL   August 08  ...
# 221105  Semiconductors were real outperformers last ye...
# 221141  Shares of Nvidia   NASDAQ NVDA   are up nearly...
# 221468  For Immediate Release\n\nChicago  IL   July 22...
#
#        content_NVIDIA_topic release_date                   provider  \
# 78                     True   2020-01-12  Zacks Investment Research
# 187                    True   2019-12-02  Zacks Investment Research
# 196                    True   2019-11-25  Zacks Investment Research
# 665                    True   2019-06-20  Zacks Investment Research
# 691                    True   2019-06-19  Zacks Investment Research
# ...                     ...          ...                        ...
# 221049                 True   2017-07-26  Zacks Investment Research
# 221052                 True   2017-08-07  Zacks Investment Research
# 221105                 True   2017-04-11             Taki Tsaklanos
# 221141                 True   2016-09-27  Zacks Investment Research
# 221468                 True   2016-07-21  Zacks Investment Research
#
#                                                       url  article_id
# 78      https://www.investing.com/analysis/the-zacks-a...   200498277
# 187     https://www.investing.com/analysis/the-zacks-a...   200489587
# 196     https://www.investing.com/analysis/nvidia-gree...   200488165
# 665     https://www.investing.com/analysis/the-zacks-a...   200433642
# 691     https://www.investing.com/analysis/nvidia-push...   200432829
# ...                                                   ...         ...
# 221049  https://www.investing.com/analysis/nvidia-(nvd...   200203731
# 221052  https://www.investing.com/analysis/the-zacks-a...   200205961
# 221105  https://www.investing.com/analysis/double-top-...   200182123
# 221141  https://www.investing.com/analysis/here's-why-...   200155860
# 221468  https://www.investing.com/analysis/zacks.com-f...   200143537
#
# [595 rows x 11 columns]

# %% [markdown]
# # While there are 102 articles that have the ticker NVDA but do not have NVIDIA as a topic

# %%
news_articles_data[(news_articles_data['ticker'] == "NVDA")]
# Out:
#             id ticker                                              title  \
# 199182  420698   NVDA  NVIDIA Officially Launches Game Streaming Serv...
# 199183  420699   NVDA  Should You Buy NVIDIA Stock At Its Current Val...
# 199184  420700   NVDA  NVIDIA s New Cloud Service Could Spell Doom fo...
# 199185  420701   NVDA  Amazon pulls out of major Barcelona telecoms c...
# 199186  420702   NVDA                              NVIDIA Stock Rises 3
# ...        ...    ...                                                ...
# 200682  422198   NVDA  Groupon  GRPN  Q3 Earnings In Line  Revenues M...
# 200699  422215   NVDA  Is Hubspot  HUBS  Likely To Beat Q3 Earnings E...
# 200700  422216   NVDA  Key Factors Likely To Impact CDW Corp s  CDW  ...
# 200708  422224   NVDA  Insperity  NSP  To Report Q3 Earnings  What s ...
# 200709  422225   NVDA  Key Factors To Look For Ahead Of FireEye  FEYE...
#
#        title_NVIDIA_topic category  \
# 199182               True     news
# 199183               True     news
# 199184               True     news
# 199185              False     news
# 199186               True     news
# ...                   ...      ...
# 200682              False  opinion
# 200699              False  opinion
# 200700              False  opinion
# 200708              False  opinion
# 200709              False  opinion
#
#                                                   content  \
# 199182  Computer hardware company NVIDIA  NASDAQ NVDA ...
# 199183  NVIDIA  NASDAQ NVDA  stock has regained its mo...
# 199184  NVIDIA  NASDAQ NVDA  recently ended a three ye...
# 199185  BERLIN MADRID  Reuters    Amazon com Inc  O AM...
# 199186  Investing com   NVIDIA  NASDAQ NVDA  Stock ros...
# ...                                                   ...
# 200682  Groupon Inc    NASDAQ GRPN   reported non GAAP...
# 200699  HubSpot  Inc    NYSE HUBS   is set to release ...
# 200700  CDW Corporation   NASDAQ CDW   is scheduled to...
# 200708  Insperity Inc   NYSE NSP   is set to release t...
# 200709  FireEye Inc    NASDAQ FEYE   is slated to rele...
#
#        content_NVIDIA_topic release_date                   provider  \
# 199182                 True   2020-02-04            The Motley Fool
# 199183                 True   2020-02-06            The Motley Fool
# 199184                 True   2020-02-07            The Motley Fool
# 199185                 True   2020-02-09                    Reuters
# 199186                 True   2020-02-10              Investing.com
# ...                     ...          ...                        ...
# 200682                 True   2017-11-01  Zacks Investment Research
# 200699                 True   2017-10-30  Zacks Investment Research
# 200700                 True   2017-10-30  Zacks Investment Research
# 200708                 True   2017-10-29  Zacks Investment Research
# 200709                 True   2017-10-29  Zacks Investment Research
#
#                                                       url  article_id
# 199182                             https://invst.ly/pr2w3     2076127
# 199183                             https://invst.ly/pr-h2     2077999
# 199184                             https://invst.ly/psg2m     2079105
# 199185  https://www.investing.com/news/technology-news...     2080109
# 199186  https://www.investing.com/news/stock-market-ne...     2080766
# ...                                                   ...         ...
# 200682  https://www.investing.com/analysis/groupon-grp...   200257908
# 200699  https://www.investing.com/analysis/is-hubspot-...   200257134
# 200700  https://www.investing.com/analysis/key-factors...   200257037
# 200708  https://www.investing.com/analysis/insperity-n...   200257112
# 200709  https://www.investing.com/analysis/key-factors...   200257054
#
# [415 rows x 11 columns]

# %%
news_articles_data[(news_articles_data['ticker'] == "NVDA") | (news_articles_data['title_NVIDIA_topic'] == True)]
# Out:
#             id ticker                                              title  \
# 78      221593   UBER  The Zacks Analyst Blog Highlights  Advanced Mi...
# 187     221702   UBER  The Zacks Analyst Blog Highlights  Toyota Moto...
# 196     221711   UBER  NVIDIA  Greenbrier  Uber  Amazon And Apple Hig...
# 665     222180   UBER  The Zacks Analyst Blog Highlights  Alphabet  T...
# 691     222206   UBER  NVIDIA Pushes Self Drive Efforts  Must INTC  Q...
# ...        ...    ...                                                ...
# 221049  442565    AMD  Nvidia  NVDA  Hits All Time High After Strong ...
# 221052  442568    AMD  The Zacks Analyst Blog Highlights  Nvidia  AMD...
# 221105  442621    AMD  Double Top In NVIDIA  Time To Short Sell Semic...
# 221141  442657    AMD    Here s Why Nvidia  NVDA  Stock Is Gaining Today
# 221468  442984      T  Zacks com Featured Highlights  AT T  Nu Skin E...
#
#        title_NVIDIA_topic category  \
# 78                   True  opinion
# 187                  True  opinion
# 196                  True  opinion
# 665                  True  opinion
# 691                  True  opinion
# ...                   ...      ...
# 221049               True  opinion
# 221052               True  opinion
# 221105               True  opinion
# 221141               True  opinion
# 221468               True  opinion
#
#                                                   content  \
# 78      For Immediate ReleaseChicago  IL   January 13 ...
# 187     For Immediate ReleaseChicago  IL   December 3 ...
# 196     For Immediate ReleaseChicago  IL   November 26...
# 665     For Immediate Release\nChicago  IL   June 21  ...
# 691     NVIDIA Corporation s   NASDAQ NVDA   latest co...
# ...                                                   ...
# 221049  During the first trading period after AMD s   ...
# 221052  For Immediate ReleaseChicago  IL   August 08  ...
# 221105  Semiconductors were real outperformers last ye...
# 221141  Shares of Nvidia   NASDAQ NVDA   are up nearly...
# 221468  For Immediate Release\n\nChicago  IL   July 22...
#
#        content_NVIDIA_topic release_date                   provider  \
# 78                     True   2020-01-12  Zacks Investment Research
# 187                    True   2019-12-02  Zacks Investment Research
# 196                    True   2019-11-25  Zacks Investment Research
# 665                    True   2019-06-20  Zacks Investment Research
# 691                    True   2019-06-19  Zacks Investment Research
# ...                     ...          ...                        ...
# 221049                 True   2017-07-26  Zacks Investment Research
# 221052                 True   2017-08-07  Zacks Investment Research
# 221105                 True   2017-04-11             Taki Tsaklanos
# 221141                 True   2016-09-27  Zacks Investment Research
# 221468                 True   2016-07-21  Zacks Investment Research
#
#                                                       url  article_id
# 78      https://www.investing.com/analysis/the-zacks-a...   200498277
# 187     https://www.investing.com/analysis/the-zacks-a...   200489587
# 196     https://www.investing.com/analysis/nvidia-gree...   200488165
# 665     https://www.investing.com/analysis/the-zacks-a...   200433642
# 691     https://www.investing.com/analysis/nvidia-push...   200432829
# ...                                                   ...         ...
# 221049  https://www.investing.com/analysis/nvidia-(nvd...   200203731
# 221052  https://www.investing.com/analysis/the-zacks-a...   200205961
# 221105  https://www.investing.com/analysis/double-top-...   200182123
# 221141  https://www.investing.com/analysis/here's-why-...   200155860
# 221468  https://www.investing.com/analysis/zacks.com-f...   200143537
#
# [1010 rows x 11 columns]

# %%
news_articles_data[(news_articles_data['ticker'] == "NVDA") | (
            (news_articles_data['title_NVIDIA_topic'] == True) | (news_articles_data['content_NVIDIA_topic'] == True))]
# Out:
#             id ticker                                              title  \
# 24      221539    NIO  A Central Bank War Just Started And Its Good F...
# 32      221547    NIO         6 Stocks To Watch  Nivida Could Be Falling
# 57      221572    NIO  Stocks   Dow Drops Nearly 400 Points as Apple ...
# 78      221593   UBER  The Zacks Analyst Blog Highlights  Advanced Mi...
# 82      221597   UBER                     The Best Of CES 2020  Revised
# ...        ...    ...                                                ...
# 221141  442657    AMD    Here s Why Nvidia  NVDA  Stock Is Gaining Today
# 221166  442682    AMD      4 Stocks To Watch Today  ATW  CWEI  MXL  SLCA
# 221189  442705    AMD  Here s What The Buy Side Expects From AMD Thur...
# 221468  442984      T  Zacks com Featured Highlights  AT T  Nu Skin E...
# 221471  442987      T  5 Dividend Growth Stocks To Sail Through Uncer...
#
#        title_NVIDIA_topic category  \
# 24                  False  opinion
# 32                  False  opinion
# 57                  False     news
# 78                   True  opinion
# 82                  False  opinion
# ...                   ...      ...
# 221141               True  opinion
# 221166              False  opinion
# 221189              False  opinion
# 221468               True  opinion
# 221471              False  opinion
#
#                                                   content  \
# 24      ECB Effects\nThe move in the euro was huge  fa...
# 32      6 Stocks To Watch  March 6 Trading Session\nSt...
# 57      Investing com   A rout in Apple and Facebook  ...
# 78      For Immediate ReleaseChicago  IL   January 13 ...
# 82      With 4 500 companies bringing their innovation...
# ...                                                   ...
# 221141  Shares of Nvidia   NASDAQ NVDA   are up nearly...
# 221166  It was a pretty good start to the week on Mond...
# 221189  Advanced Micro Devices Inc   NYSE AMD  is set ...
# 221468  For Immediate Release\n\nChicago  IL   July 22...
# 221471  With uncertainty ruling the markets since the ...
#
#        content_NVIDIA_topic release_date                   provider  \
# 24                     True   2019-03-07             Michael Kramer
# 32                     True   2019-03-06             Michael Kramer
# 57                     True   2018-11-19              Investing.com
# 78                     True   2020-01-12  Zacks Investment Research
# 82                     True   2020-01-16  Zacks Investment Research
# ...                     ...          ...                        ...
# 221141                 True   2016-09-27  Zacks Investment Research
# 221166                 True   2016-05-17                Harry Boxer
# 221189                 True   2014-04-17                   Estimize
# 221468                 True   2016-07-21  Zacks Investment Research
# 221471                 True   2016-07-20  Zacks Investment Research
#
#                                                       url  article_id
# 24      https://www.investing.com/analysis/a-central-b...   200395687
# 32      https://www.investing.com/analysis/6-stocks-to...   200394931
# 57      https://www.investing.com/news/stock-market-ne...     1694042
# 78      https://www.investing.com/analysis/the-zacks-a...   200498277
# 82      https://www.investing.com/analysis/the-best-of...   200499164
# ...                                                   ...         ...
# 221141  https://www.investing.com/analysis/here's-why-...   200155860
# 221166  https://www.investing.com/analysis/atw,-cwei,-...   200130262
# 221189  https://www.investing.com/analysis/here’s-what...      209915
# 221468  https://www.investing.com/analysis/zacks.com-f...   200143537
# 221471  https://www.investing.com/analysis/5-dividend-...   200143306
#
# [3464 rows x 11 columns]

# %%
def add_improved_NVDA_ticker_column(df):
    improved_ticker_column = insert_empty_column_to_df(df=df,
                                                       original_column="ticker",
                                                       extension="NVDA_improved")
    for index, row in df.iterrows():
        # if NVDA is ticker but NVDA is not mentioned in the topic or in the content, so must be mistake
        # :TODO remove this clause because the the articles are about it?    
        # ticker is not NVDA but NVIDA is mentioned in the topic or in the content
        if (row['ticker'] != "NVDA") & ((row['title_NVIDIA_topic'] == True) | (row['content_NVIDIA_topic'] == True)):
            df.at[index, improved_ticker_column] = True
        #NVIDA is the ticker
        elif row['ticker'] == "NVDA":
            df.at[index, improved_ticker_column] = True
        else:
            df.at[index, improved_ticker_column] = False


add_improved_NVDA_ticker_column(news_articles_data)
# Out:
# /var/folders/f3/ykt1vfz96xz48try_trwdn440000gn/T/ipykernel_57538/2011023923.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, improved_ticker_column] = False

# %% [markdown]
# # Filter only the NVIDIA articles
#
# We are only going to take the articles that are related to NVIDIA, therefore we filter the articles based on the improved NVDA ticker symbol. Since in the original article, multiple tickers are connected to each article. but in the dataset, only a single ticker is associated with each article

# %%
new_articles_nvidia = news_articles_data[news_articles_data["ticker_NVDA_improved"] == True]
new_articles_nvidia
# Out:
#             id ticker ticker_NVDA_improved  \
# 24      221539    NIO                 True
# 32      221547    NIO                 True
# 57      221572    NIO                 True
# 78      221593   UBER                 True
# 82      221597   UBER                 True
# ...        ...    ...                  ...
# 221141  442657    AMD                 True
# 221166  442682    AMD                 True
# 221189  442705    AMD                 True
# 221468  442984      T                 True
# 221471  442987      T                 True
#
#                                                     title title_NVIDIA_topic  \
# 24      A Central Bank War Just Started And Its Good F...              False
# 32             6 Stocks To Watch  Nivida Could Be Falling              False
# 57      Stocks   Dow Drops Nearly 400 Points as Apple ...              False
# 78      The Zacks Analyst Blog Highlights  Advanced Mi...               True
# 82                         The Best Of CES 2020  Revised               False
# ...                                                   ...                ...
# 221141    Here s Why Nvidia  NVDA  Stock Is Gaining Today               True
# 221166      4 Stocks To Watch Today  ATW  CWEI  MXL  SLCA              False
# 221189  Here s What The Buy Side Expects From AMD Thur...              False
# 221468  Zacks com Featured Highlights  AT T  Nu Skin E...               True
# 221471  5 Dividend Growth Stocks To Sail Through Uncer...              False
#
#        category                                            content  \
# 24      opinion  ECB Effects\nThe move in the euro was huge  fa...
# 32      opinion  6 Stocks To Watch  March 6 Trading Session\nSt...
# 57         news  Investing com   A rout in Apple and Facebook  ...
# 78      opinion  For Immediate ReleaseChicago  IL   January 13 ...
# 82      opinion  With 4 500 companies bringing their innovation...
# ...         ...                                                ...
# 221141  opinion  Shares of Nvidia   NASDAQ NVDA   are up nearly...
# 221166  opinion  It was a pretty good start to the week on Mond...
# 221189  opinion  Advanced Micro Devices Inc   NYSE AMD  is set ...
# 221468  opinion  For Immediate Release\n\nChicago  IL   July 22...
# 221471  opinion  With uncertainty ruling the markets since the ...
#
#        content_NVIDIA_topic release_date                   provider  \
# 24                     True   2019-03-07             Michael Kramer
# 32                     True   2019-03-06             Michael Kramer
# 57                     True   2018-11-19              Investing.com
# 78                     True   2020-01-12  Zacks Investment Research
# 82                     True   2020-01-16  Zacks Investment Research
# ...                     ...          ...                        ...
# 221141                 True   2016-09-27  Zacks Investment Research
# 221166                 True   2016-05-17                Harry Boxer
# 221189                 True   2014-04-17                   Estimize
# 221468                 True   2016-07-21  Zacks Investment Research
# 221471                 True   2016-07-20  Zacks Investment Research
#
#                                                       url  article_id
# 24      https://www.investing.com/analysis/a-central-b...   200395687
# 32      https://www.investing.com/analysis/6-stocks-to...   200394931
# 57      https://www.investing.com/news/stock-market-ne...     1694042
# 78      https://www.investing.com/analysis/the-zacks-a...   200498277
# 82      https://www.investing.com/analysis/the-best-of...   200499164
# ...                                                   ...         ...
# 221141  https://www.investing.com/analysis/here's-why-...   200155860
# 221166  https://www.investing.com/analysis/atw,-cwei,-...   200130262
# 221189  https://www.investing.com/analysis/here’s-what...      209915
# 221468  https://www.investing.com/analysis/zacks.com-f...   200143537
# 221471  https://www.investing.com/analysis/5-dividend-...   200143306
#
# [3464 rows x 12 columns]

# %% [markdown]
# # Adding the label of increase or decrease in stock price
#
# Here I will create labels for each related article, to determine if stock price of NVIDIA increased or decreased at the end of the day.
#
# I want to create a dictionary, where each day is the key, and the value is if the closing price is higher or lower than the opening price. The value will be 1 if the closing price is equal or greater than the open price, 0 when the closing price is lower than the opening price

# %%
stock_data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1999-01-25    0.044271    0.045833    0.041016    0.045313    0.041562
# 1     1999-01-26    0.045833    0.046745    0.041146    0.041797    0.038337
# 2     1999-01-27    0.041927    0.042969    0.039583    0.041667    0.038218
# 3     1999-01-28    0.041667    0.041927    0.041276    0.041536    0.038098
# 4     1999-01-29    0.041536    0.041667    0.039583    0.039583    0.036307
# ...          ...         ...         ...         ...         ...         ...
# 6432  2024-08-16  121.940002  125.000000  121.180000  124.580002  124.580002
# 6433  2024-08-19  124.279999  130.000000  123.419998  130.000000  130.000000
# 6434  2024-08-20  128.399994  129.880005  125.889999  127.250000  127.250000
# 6435  2024-08-21  127.320000  129.350006  126.660004  128.500000  128.500000
# 6436  2024-08-22  130.029999  130.750000  128.800003  128.929901  128.929901
#
#          Volume
# 0     510480000
# 1     343200000
# 2     244368000
# 3     227520000
# 4     244032000
# ...         ...
# 6432  302589900
# 6433  318333600
# 6434  300087400
# 6435  256985000
# 6436   63358287
#
# [6437 rows x 7 columns]

# %%
def create_opening_closing_dict_stock_data(stock_df):
    increase_start_closing_time_dict = {}
    for index, row in stock_df.iterrows():
        if row["Close"] >= row["Open"]:
            increase_start_closing_time_dict[row["Date"]] = 1
        else:
            increase_start_closing_time_dict[row["Date"]] = 0
    return increase_start_closing_time_dict
stock_increase_close_dict = create_opening_closing_dict_stock_data(stock_data)
stock_increase_close_df = pd.DataFrame.from_dict({"date": stock_increase_close_dict.keys(), "NVIDIA_increase": stock_increase_close_dict.values()})
stock_increase_close_df
# Out:
#             date  NVIDIA_increase
# 0     1999-01-25                1
# 1     1999-01-26                0
# 2     1999-01-27                0
# 3     1999-01-28                0
# 4     1999-01-29                0
# ...          ...              ...
# 6432  2024-08-16                1
# 6433  2024-08-19                1
# 6434  2024-08-20                0
# 6435  2024-08-21                1
# 6436  2024-08-22                0
#
# [6437 rows x 2 columns]

# %%
def get_nvidia_increased_bool(date_to_find, increase_stock_dict):
    """
    checks the date to find in the increase_stock_dict. If the date is missing, it tries to find the nearest previous date where the increase stock date is available
    :param date_to_find: 
    :param increase_stock_dict: 
    :return: 
    """
    if date_to_find in increase_stock_dict:
        return increase_stock_dict[date_to_find]
    for num in range(1, 10):
        date_time_object_to_find = datetime.datetime.strptime(date_to_find, "%Y-%m-%d") - datetime.timedelta(num)
        date_reduction_string = date_time_object_to_find.strftime("%Y-%m-%d")
        if date_reduction_string in increase_stock_dict:
            return increase_stock_dict[date_reduction_string]

def add_NVIDIA_stock_increased_column(df_news, increase_stock_dict):
    if "NVIDIA_stock_increase" not in df_news:
        df_news["NVIDIA_stock_increase"] = ""
    
    for index, row in df_news.iterrows():
        date_article = row["release_date"]
        nvidia_increased = get_nvidia_increased_bool(date_article, increase_stock_dict)
        df_news.at[index, "NVIDIA_stock_increase"] = nvidia_increased
        
add_NVIDIA_stock_increased_column(new_articles_nvidia, stock_increase_close_dict)
new_articles_nvidia
# Out:
#             id ticker ticker_NVDA_improved  \
# 24      221539    NIO                 True
# 32      221547    NIO                 True
# 57      221572    NIO                 True
# 78      221593   UBER                 True
# 82      221597   UBER                 True
# ...        ...    ...                  ...
# 221141  442657    AMD                 True
# 221166  442682    AMD                 True
# 221189  442705    AMD                 True
# 221468  442984      T                 True
# 221471  442987      T                 True
#
#                                                     title title_NVIDIA_topic  \
# 24      A Central Bank War Just Started And Its Good F...              False
# 32             6 Stocks To Watch  Nivida Could Be Falling              False
# 57      Stocks   Dow Drops Nearly 400 Points as Apple ...              False
# 78      The Zacks Analyst Blog Highlights  Advanced Mi...               True
# 82                         The Best Of CES 2020  Revised               False
# ...                                                   ...                ...
# 221141    Here s Why Nvidia  NVDA  Stock Is Gaining Today               True
# 221166      4 Stocks To Watch Today  ATW  CWEI  MXL  SLCA              False
# 221189  Here s What The Buy Side Expects From AMD Thur...              False
# 221468  Zacks com Featured Highlights  AT T  Nu Skin E...               True
# 221471  5 Dividend Growth Stocks To Sail Through Uncer...              False
#
#        category                                            content  \
# 24      opinion  ECB Effects\nThe move in the euro was huge  fa...
# 32      opinion  6 Stocks To Watch  March 6 Trading Session\nSt...
# 57         news  Investing com   A rout in Apple and Facebook  ...
# 78      opinion  For Immediate ReleaseChicago  IL   January 13 ...
# 82      opinion  With 4 500 companies bringing their innovation...
# ...         ...                                                ...
# 221141  opinion  Shares of Nvidia   NASDAQ NVDA   are up nearly...
# 221166  opinion  It was a pretty good start to the week on Mond...
# 221189  opinion  Advanced Micro Devices Inc   NYSE AMD  is set ...
# 221468  opinion  For Immediate Release\n\nChicago  IL   July 22...
# 221471  opinion  With uncertainty ruling the markets since the ...
#
#        content_NVIDIA_topic release_date                   provider  \
# 24                     True   2019-03-07             Michael Kramer
# 32                     True   2019-03-06             Michael Kramer
# 57                     True   2018-11-19              Investing.com
# 78                     True   2020-01-12  Zacks Investment Research
# 82                     True   2020-01-16  Zacks Investment Research
# ...                     ...          ...                        ...
# 221141                 True   2016-09-27  Zacks Investment Research
# 221166                 True   2016-05-17                Harry Boxer
# 221189                 True   2014-04-17                   Estimize
# 221468                 True   2016-07-21  Zacks Investment Research
# 221471                 True   2016-07-20  Zacks Investment Research
#
#                                                       url  article_id  \
# 24      https://www.investing.com/analysis/a-central-b...   200395687
# 32      https://www.investing.com/analysis/6-stocks-to...   200394931
# 57      https://www.investing.com/news/stock-market-ne...     1694042
# 78      https://www.investing.com/analysis/the-zacks-a...   200498277
# 82      https://www.investing.com/analysis/the-best-of...   200499164
# ...                                                   ...         ...
# 221141  https://www.investing.com/analysis/here's-why-...   200155860
# 221166  https://www.investing.com/analysis/atw,-cwei,-...   200130262
# 221189  https://www.investing.com/analysis/here’s-what...      209915
# 221468  https://www.investing.com/analysis/zacks.com-f...   200143537
# 221471  https://www.investing.com/analysis/5-dividend-...   200143306
#
#        NVIDIA_stock_increase
# 24                         0
# 32                         0
# 57                         0
# 78                         0
# 82                         1
# ...                      ...
# 221141                     1
# 221166                     1
# 221189                     1
# 221468                     0
# 221471                     1
#
# [3464 rows x 13 columns]

# %% [markdown]
# # Domain
# I assume the domain is news, since we have a news article dataset. So the the writing style will be understandable for the audience of news readers, which may differ a lot depending on the news outline. But it will probably be not super technical and jargon heavy. For the language, I also do not know what language the data is from, but from initial viewing, it is prodomnatly engish. The language will be dependent on the provider of the news article, and the language of articles from a distinct provider will probably stay constant.

# %% [markdown]
# ### Corpus characteristics
#
# The corpus of data consists of inidivudal news articles content and its title.
# - the format of the text is plain text.
# - The encoding is not yet determined, currently we read the csv with encoding UTF-8, we do not see unknown characters, so it is probably correct. We do have to test this further
# - Text unit
#     - title: sentence of words
#     - news article content: paragraphs consisting of sentences of words
# - length of text: undermined for now, we must check this later
#
#
# ### Corpus documents understanding
# - Vocuabulary: How rich is the text, what is the lexical variation of the text?
# - corpus homogeneity: the news articles will be filtered for articles that relate to NVIDIA. therefore the resulting data, will be quite homogenous, but since different providers can have written the text, the text will be more homogenous of articles between the same provider about NVIDIA compared to articles from other providers that are about NVIDIA
# -

# %% [markdown]
# ## Data understanding
# - the number of documents (equal to number of rows which equals news articles) in the complete corpus = 221513 news articles
# - number of documents that relate to NVIDA?
# - Number of average documents per news provider
# - proportion of documents that are about NVIDIA per news provider
# - proportion of documents that are about NVIDIA corpus as a whole
# - average words per article
#     - corpus as a whole
#     - per news provider
#     - per article that is about NVIDIA
#     - per article that is about NVIDIA per news provider
# - Frequently occurring words
#     - when the topic is NVIDIA
#     - when the topic is not NVIDIA
#     - we can make this also specific for each news provider, to see if there are differences
#     - What is the lexical variation for each of these different interpretations of frequently occurring words?
# - Average sentence length
#     -  when the topic is NVIDIA
#     - when the topic is not NVIDIA
#     - we can make this also specific for each news provider, to see if there are differences

# %% [markdown]
# # Preprocessing the text
# In the data we can see that there are no "." periods, we cannot tell you why. But this is what we see. We replace "\n" with a space (" "). This is necessary because sometimes the \n is creating a new line but there is immediately a character. So in order to get correct tokens we have to replace the \n with a space, because we determine the tokens with spaces.
#
# Also in the text there are no commas, likely because they were removed before adding it to the dataset because the csv makes use of comma's, to separate the columns.
#
# Also all "'" have been removed in the text, so we can choose to bring them back or leave them. We could bring them back by just adding them. but we can also just remove the single character tokens.
#
# We choose to analyze the text in lowercase, so we assume that capital letters have no added value in the text, this is done to simplify the model and training.

# %%
def turn_text_into_tokens(text):
    try:
        return nltk.tokenize.regexp_tokenize(text.lower(), r"[\w']+")
    except TypeError:
        print(text)
        return []
    except AttributeError:
        print(text)
        return []

def turn_text_into_tokens_old(text):
    try:
        return [word for word in re.split(" ",text.replace("\n", " ").replace("\\", "")) if word != "" ]
    except TypeError:
        print(text)



def initialize_count_dict():
    return defaultdict(lambda : 0)

def add_list_tokens_to_count_dict(token_list, token_count_dict):
    for token in token_list:
        token_count_dict[token] += 1

def add_nr_words_column_of_text(df, column_name_to_count):
    """
    
    :param df: df to process
    :param column_name_to_count: the column name to count the nr of words present
    :return: 
    """
    nr_word_column_name = insert_empty_column_to_df(df=df,
                                                     original_column=column_name_to_count,
                                                     extension="nr_words")
    
    token_text_column_name = insert_empty_column_to_df(df=df,
                                                       original_column=column_name_to_count,
                                                       extension="tokenized")
    
    token_count_dict = initialize_count_dict()
    
    
    for index, row in df.iterrows():
        list_of_tokens = turn_text_into_tokens(row[column_name_to_count])
        add_list_tokens_to_count_dict(list_of_tokens, token_count_dict)
        news_articles_data.at[index, nr_word_column_name] = len(list_of_tokens)
        
        #news_articles_data.at[index, token_text_column_name] = turn_text_into_tokens(row[column_name_to_count])
    
    return token_count_dict
        

title_token_count_dict = add_nr_words_column_of_text(df=news_articles_data, column_name_to_count="title")
content_token_count_dict = add_nr_words_column_of_text(df=news_articles_data, column_name_to_count="content")
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
def calculate_unique_words_count_dict(token_count_dict):
    return len(token_count_dict.keys())

def calculate_lexical_richness_count_dict(token_count_dict):
    total_tokens = sum(token_count_dict.values())
    unique_token_count = calculate_unique_words_count_dict(token_count_dict)
    lexical_richness = unique_token_count/total_tokens
    return lexical_richness

print(f"unique tokens in title = {calculate_unique_words_count_dict(title_token_count_dict)}")
print(f"lexical richness title = {calculate_lexical_richness_count_dict(title_token_count_dict)}")
print(f"unique tokens in content = {calculate_unique_words_count_dict(content_token_count_dict)}")
print(f"lexical richness content = {calculate_lexical_richness_count_dict(content_token_count_dict)}")
# Out:
# unique tokens in title = 43594
# lexical richness title = 0.020432842158942522
# unique tokens in content = 343205
# lexical richness content = 0.0026110105318657476

# %%
def show_most_common_words(token_count_dict, amount_to_show):
    sorted_token_count = sorted(token_count_dict.items(), reverse=True, key=lambda x: x[1])
    stop_words_english = set(nltk.corpus.stopwords.words('english'))
    sorted_tokens_without_stopwords = [(word, count) for (word, count) in sorted_token_count if word not in stop_words_english]
    return sorted_tokens_without_stopwords[:amount_to_show]

# %% [markdown]
# ### Most 50 common words in title

# %%
show_most_common_words(title_token_count_dict, 50)
# Out:
# [('earnings', 35273),
#  ('stocks', 23389),
#  ('stock', 17802),
#  ('u', 17568),
#  ('estimates', 8814),
#  ('trade', 8792),
#  ('market', 8337),
#  ('0', 7361),
#  ('buy', 7292),
#  ('top', 7279),
#  ('3', 7264),
#  ('5', 7202),
#  ('q3', 7082),
#  ('new', 7032),
#  ('beat', 7022),
#  ('q4', 6880),
#  ('q1', 6765),
#  ('higher', 6495),
#  ('q2', 6153),
#  ('report', 6111),
#  ('revenues', 5737),
#  ('1', 5683),
#  ('china', 5619),
#  ('growth', 5296),
#  ('sales', 5234),
#  ('apple', 5168),
#  ('zacks', 5086),
#  ('oil', 5008),
#  ('week', 5004),
#  ('data', 4908),
#  ('ahead', 4888),
#  ('close', 4872),
#  ('dow', 4853),
#  ('shares', 4650),
#  ('deal', 4500),
#  ('highlights', 4437),
#  ('4', 4416),
#  ('lower', 4275),
#  ('2', 4148),
#  ('investors', 4026),
#  ('beats', 4012),
#  ('wall', 3981),
#  ('says', 3951),
#  ('amazon', 3861),
#  ('high', 3852),
#  ('revenue', 3794),
#  ('markets', 3716),
#  ('us', 3454),
#  ('analyst', 3420),
#  ('watch', 3335)]

# %% [markdown]
# ### Most common 50 words in title

# %%
show_most_common_words(content_token_count_dict, 50)
# Out:
# [('year', 782698),
#  ('1', 681246),
#  ('company', 609021),
#  ('zacks', 550140),
#  ('earnings', 545103),
#  ('2', 490316),
#  ('quarter', 446426),
#  ('3', 417846),
#  ('0', 366000),
#  ('million', 362236),
#  ('market', 352341),
#  ('nyse', 350764),
#  ('said', 349662),
#  ('stocks', 345264),
#  ('growth', 340129),
#  ('5', 317852),
#  ('billion', 313879),
#  ('stock', 309927),
#  ('u', 306092),
#  ('also', 297995),
#  ('4', 283341),
#  ('nasdaq', 283242),
#  ('new', 258213),
#  ('rank', 258053),
#  ('last', 253648),
#  ('inc', 252910),
#  ('6', 233607),
#  ('7', 225596),
#  ('expected', 224482),
#  ('per', 220201),
#  ('estimate', 214955),
#  ('investors', 213993),
#  ('share', 206731),
#  ('8', 204428),
#  ('percent', 204289),
#  ('sales', 202868),
#  ('consensus', 201089),
#  ('price', 197400),
#  ('one', 194272),
#  ('shares', 191346),
#  ('buy', 174155),
#  ('first', 173036),
#  ('9', 170928),
#  ('may', 170830),
#  ('would', 170574),
#  ('time', 170510),
#  ('companies', 168683),
#  ('p', 166933),
#  ('revenues', 165225),
#  ('see', 164647)]

# %%
news_articles_data.describe()
# Out:
#                   id  title_tokenized  title_nr_words  content_tokenized  \
# count  221513.000000         221513.0   221513.000000           221513.0
# mean   332271.337872              0.0        9.631606                0.0
# std     63945.826913              0.0        2.502070                0.0
# min    221515.000000              0.0        1.000000                0.0
# 25%    276893.000000              0.0        8.000000                0.0
# 50%    332271.000000              0.0       10.000000                0.0
# 75%    387650.000000              0.0       11.000000                0.0
# max    443028.000000              0.0       38.000000                0.0
#
#        content_nr_words    article_id
# count     221513.000000  2.215130e+05
# mean         593.397570  9.510278e+07
# std          516.293322  9.956825e+07
# min            0.000000  6.690000e+02
# 25%          336.000000  4.657470e+05
# 50%          522.000000  2.038949e+06
# 75%          745.000000  2.003073e+08
# max        24908.000000  2.005073e+08

# %%
sns.pairplot(news_articles_data[['title_nr_words', 'content_nr_words']])

# %% [markdown]
# # Filter the documents that are important and related to NVIDIA

# %%
# Out:
# /var/folders/f3/ykt1vfz96xz48try_trwdn440000gn/T/ipykernel_56861/3310194756.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, title_column_name] = check_article_NVIDA_keyword_match(row["title"])
# /var/folders/f3/ykt1vfz96xz48try_trwdn440000gn/T/ipykernel_56861/3310194756.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, content_column_name] = check_article_NVIDA_keyword_match(row["content"])
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
#             id ticker                                              title  \
# 0       221515    NIO  Why Shares of Chinese Electric Car Maker NIO A...
# 1       221516    NIO  NIO only consumer gainer  Workhorse Group amon...
# 2       221517    NIO  NIO leads consumer gainers  Beyond Meat and Ma...
# 3       221518    NIO                  NIO  NVAX among premarket gainers
# 4       221519    NIO                  PLUG  NIO among premarket gainers
# ...        ...    ...                                                ...
# 221508  443024      T                     Crude And Steel Still In Sync
# 221509  443025      T  Forget AT T  This Is The Telecom Stock You Sho...
# 221510  443026      T  Wall Street Exposed   Part 3   How Dividends C...
# 221511  443027      T       Weighing The Week Ahead  It s All About Jobs
# 221512  443028      T  Leap Wireless  LEAP    JPM Note and AT T   T M...
#
#        title_NVIDIA_topic  title_tokenized  title_nr_words category  \
# 0                   False                0              12     news
# 1                   False                0               8     news
# 2                   False                0              10     news
# 3                   False                0               5     news
# 4                   False                0               5     news
# ...                   ...              ...             ...      ...
# 221508              False                0               6  opinion
# 221509              False                0              11  opinion
# 221510              False                0               9  opinion
# 221511              False                0               9  opinion
# 221512              False                0              15  opinion
#
#                                                   content  \
# 0       What s happening\nShares of Chinese electric c...
# 1       Gainers  NIO  NYSE NIO   7  \nLosers  MGP Ingr...
# 2       Gainers  NIO  NYSE NIO   14   Village Farms In...
# 3       Cemtrex  NASDAQ CETX   85  after FY results \n...
# 4       aTyr Pharma  NASDAQ LIFE   63  on Kyorin Pharm...
# ...                                                   ...
# 221508  We have been reporting on the trade off betwee...
# 221509  It s the largest cell phone provider in the wo...
# 221510  Before we dicuss how the mechanism of dividend...
# 221511  From start to finish  the coming week will hav...
# 221512  Leap Wireless International  Inc   Leap  is a ...
#
#        content_NVIDIA_topic  content_tokenized  content_nr_words release_date  \
# 0                     False                  0               272   2020-01-15
# 1                     False                  0                22   2020-01-18
# 2                     False                  0                51   2020-01-15
# 3                     False                  0               115   2020-01-15
# 4                     False                  0               198   2020-01-06
# ...                     ...                ...               ...          ...
# 221508                False                  0               472   2012-10-04
# 221509                False                  0               688   2012-05-30
# 221510                False                  0              1310   2012-07-16
# 221511                False                  0              2346   2012-09-02
# 221512                False                  0               518   2011-12-31
#
#                provider                                                url  \
# 0       The Motley Fool                             https://invst.ly/pigqi
# 1         Seeking Alpha                             https://invst.ly/pje9c
# 2         Seeking Alpha                             https://invst.ly/pifmv
# 3         Seeking Alpha                             https://invst.ly/picu8
# 4         Seeking Alpha  https://seekingalpha.com/news/3529772-plug-nio...
# ...                 ...                                                ...
# 221508       Ivan Kitov  https://www.investing.com/analysis/crude-and-s...
# 221509  StreetAuthority  https://www.investing.com/analysis/forget-at-t...
# 221510   Portfolio Cafe  https://www.investing.com/analysis/wall-street...
# 221511      Jeff Miller  https://www.investing.com/analysis/weighing-th...
# 221512   Ophir Gottlieb  https://www.investing.com/analysis/leap-wirele...
#
#         article_id
# 0          2060327
# 1          2062196
# 2          2060249
# 3          2060039
# 4          2053096
# ...            ...
# 221508      138733
# 221509      124829
# 221510      129651
# 221511      134926
# 221512      110079
#
# [221513 rows x 15 columns]

# %% [markdown]
# #

# %%
news_articles_data
# Out:
#             id ticker ticker_NVDA_improved  \
# 0       221515    NIO                False
# 1       221516    NIO                False
# 2       221517    NIO                False
# 3       221518    NIO                False
# 4       221519    NIO                False
# ...        ...    ...                  ...
# 221508  443024      T                False
# 221509  443025      T                False
# 221510  443026      T                False
# 221511  443027      T                False
# 221512  443028      T                False
#
#                                                     title title_NVIDIA_topic  \
# 0       Why Shares of Chinese Electric Car Maker NIO A...              False
# 1       NIO only consumer gainer  Workhorse Group amon...              False
# 2       NIO leads consumer gainers  Beyond Meat and Ma...              False
# 3                       NIO  NVAX among premarket gainers              False
# 4                       PLUG  NIO among premarket gainers              False
# ...                                                   ...                ...
# 221508                     Crude And Steel Still In Sync               False
# 221509  Forget AT T  This Is The Telecom Stock You Sho...              False
# 221510  Wall Street Exposed   Part 3   How Dividends C...              False
# 221511       Weighing The Week Ahead  It s All About Jobs              False
# 221512  Leap Wireless  LEAP    JPM Note and AT T   T M...              False
#
#         title_tokenized  title_nr_words category  \
# 0                     0              12     news
# 1                     0               8     news
# 2                     0              10     news
# 3                     0               5     news
# 4                     0               5     news
# ...                 ...             ...      ...
# 221508                0               6  opinion
# 221509                0              11  opinion
# 221510                0               9  opinion
# 221511                0               9  opinion
# 221512                0              15  opinion
#
#                                                   content  \
# 0       What s happening\nShares of Chinese electric c...
# 1       Gainers  NIO  NYSE NIO   7  \nLosers  MGP Ingr...
# 2       Gainers  NIO  NYSE NIO   14   Village Farms In...
# 3       Cemtrex  NASDAQ CETX   85  after FY results \n...
# 4       aTyr Pharma  NASDAQ LIFE   63  on Kyorin Pharm...
# ...                                                   ...
# 221508  We have been reporting on the trade off betwee...
# 221509  It s the largest cell phone provider in the wo...
# 221510  Before we dicuss how the mechanism of dividend...
# 221511  From start to finish  the coming week will hav...
# 221512  Leap Wireless International  Inc   Leap  is a ...
#
#        content_NVIDIA_topic  content_tokenized  content_nr_words release_date  \
# 0                     False                  0               272   2020-01-15
# 1                     False                  0                22   2020-01-18
# 2                     False                  0                51   2020-01-15
# 3                     False                  0               115   2020-01-15
# 4                     False                  0               198   2020-01-06
# ...                     ...                ...               ...          ...
# 221508                False                  0               472   2012-10-04
# 221509                False                  0               688   2012-05-30
# 221510                False                  0              1310   2012-07-16
# 221511                False                  0              2346   2012-09-02
# 221512                False                  0               518   2011-12-31
#
#                provider                                                url  \
# 0       The Motley Fool                             https://invst.ly/pigqi
# 1         Seeking Alpha                             https://invst.ly/pje9c
# 2         Seeking Alpha                             https://invst.ly/pifmv
# 3         Seeking Alpha                             https://invst.ly/picu8
# 4         Seeking Alpha  https://seekingalpha.com/news/3529772-plug-nio...
# ...                 ...                                                ...
# 221508       Ivan Kitov  https://www.investing.com/analysis/crude-and-s...
# 221509  StreetAuthority  https://www.investing.com/analysis/forget-at-t...
# 221510   Portfolio Cafe  https://www.investing.com/analysis/wall-street...
# 221511      Jeff Miller  https://www.investing.com/analysis/weighing-th...
# 221512   Ophir Gottlieb  https://www.investing.com/analysis/leap-wirele...
#
#         article_id
# 0          2060327
# 1          2062196
# 2          2060249
# 3          2060039
# 4          2053096
# ...            ...
# 221508      138733
# 221509      124829
# 221510      129651
# 221511      134926
# 221512      110079
#
# [221513 rows x 16 columns]

# %%
"""- Number of average documents per news provider
- proportion of documents that are about NVIDIA per news provider 
- proportion of documents that are about NVIDIA corpus as a whole
- average words per article
    - corpus as a whole
    - per news provider
    - per article that is about NVIDIA
    - per article that is about NVIDIA per news provider
- Frequently occurring words
    - when the topic is NVIDIA 
    - when the topic is not NVIDIA
    - we can make this also specific for each news provider, to see if there are differences
    - What is the lexical variation for each of these different interpretations of frequently occurring words?
- Average sentence length
    -  when the topic is NVIDIA 
    - when the topic is not NVIDIA
    - we can make this also specific for each news provider, to see if there are differences"""

news_articles_data.groupby(by=["provider", "ticker_NVDA_improved"])["title_nr_words"].mean()
# Out:
# provider      ticker_NVDA_improved
# 247wallst     False                   10.600939
#               True                    16.666667
# 4XP           False                    6.545455
# ACFX          False                    8.000000
# AG Thorson    False                    7.666667
#                                         ...
# iFOREX        True                     7.240000
# mateusz zdyb  False                    8.500000
# news fxbase   False                    4.666667
# trade 12      False                    5.939394
#               True                     6.333333
# Name: title_nr_words, Length: 1107, dtype: float64

# %%
# Number of documents per news provider
average_docs_per_provider = news_articles_data.groupby('provider').size().mean()
# Proportion of documents about NVIDIA per news provider
nvidia_proportion_per_provider = news_articles_data.groupby('provider')['ticker_NVDA_improved'].mean()
# Proportion of documents about NVIDIA for the whole corpus
nvidia_proportion_corpus = news_articles_data['ticker_NVDA_improved'].mean()
# Average words per title in the whole corpus
average_words_title_corpus = news_articles_data['title_nr_words'].mean()
# Average words per article in the whole corpus
average_words_content_corpus = news_articles_data['content_nr_words'].mean()
# Average words per title of article per news provider
average_words_title_per_provider = news_articles_data.groupby('provider')['title_nr_words'].mean()
# Average words per article per news provider
average_words_content_per_provider = news_articles_data.groupby('provider')['content_nr_words'].mean()
# Average words per title of article that is about NVIDIA
average_words_title_nvidia = news_articles_data[news_articles_data['ticker_NVDA_improved'] == True]['title_nr_words'].mean()
# Average words per article that is about NVIDIA
average_words_nvidia = news_articles_data[news_articles_data['ticker_NVDA_improved'] == True]['content_nr_words'].mean()

# Average words per title of article about NVIDIA per news provider
average_words_title_nvidia_per_provider = news_articles_data[news_articles_data['ticker_NVDA_improved'] == True].groupby('provider')['title_nr_words'].mean()
# Average words per article about NVIDIA per news provider
average_words_nvidia_per_provider = news_articles_data[news_articles_data['ticker_NVDA_improved'] == True].groupby('provider')['content_nr_words'].mean()

# %% [markdown]
# ### Domain considerations
#
# How do we make sure that we detect if there if fake news? If most articles within a timeframe say one thing, then when a low number of articles says something completely different, it might be fake. We must read this ourself to find out. Also we can do this separately  for each provider, it is probable that when a news provider has some fake news, it might also result in more fake news when more articles from the same provider.
# - Providers that provide fake news, are more likely to have more fake news
# - Providers that do not do rigerous research about a topic and have some fake news, are more likely to have other fake news as well.
# - The country of origin of a provider might also change the perspective of a news writer. for example in china, where people are not free to say what they want to say. Are more likely to provide content that is in the same line of reasoning as the politics in the country. resulting in more fake news. BUTTTT Fake news is still news and it influences people's buying decision, thus impact the stock price.

# %% [markdown]
# # Text cleaning
# We must clean the text. there might be mistakes in the text of other content. we don't know for sure, so we have to check for problems in text, this might be provider related as well.
#
# We might also have to consider the authors name in the article, if one author writes fake news, he might write more fake news. We have to check if the name is in the article
#
# We do not need to check for float numbers, because all the punctuation is removed, the digits that consist of two numberes e.g. "5.2" are represented in the text by "5 2". Therefore, we can have a simple regular expression that checks if a token is represented by pure digits. But if the token is partly digit and partly text, we keep, because strings that consist of characters of digits and text are possibly company names.

# %%
bool(re.search(pattern=r"\d", string="no"))
# Out:
# False

# %%
def check_tokens_single_characters(token_word):
    if len(token_word) <=1:
        return False
    else:
        return True
    
def check_token_is_valid_text(token_word):
    return not bool(re.search(pattern=r"^[0-9]*$", string=token_word))
        
    
def clean_tokens_row(list_of_tokens):
    return [token for token in list_of_tokens if check_tokens_single_characters(token) and check_token_is_valid_text(token) ]

clean_tokens_row(["my", "name", "s", "25", "mehdi"])
# Out:
# ['my', 'name', 'mehdi']

# %% [markdown]
# ### Stopword removal

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
def remove_stop_words(list_of_tokens):

# %% [markdown]
# # TOkenization
# We have to think of tokenizing the words, or possible multi word tokens.

# %% [markdown]
# # Text normalization
# How will we normalize the text?
#
# If needed reduce vocabulary variation by
# - removing numbers
# (but what if you need to find dates & amounts?)
# -  removing punctuation & special characters (e.g. @#, -, *, ...)
# (but what if you need to identify sentiment?)
# - convert into lower case
# (but what if you need to find names of people & products?)
# - lemmatization or stemming
# (but what if you unnecessarily increase ambiguity?
#
# Does my corpus have a lot of variation?
# • What is the ratio of unique tokens vs. my
# total token number?
# • Is it likely that I lose information that I need?
# • How is modelling affected by the tokens I
# remove or normalize?
# • Do I remove important text context?

# %% [markdown]
# # What data to use for training
# I would like to test different things
# - Use all the corpus to train the word2vec
# - Use only the corpus that have NVIDIA/NVDA as keywords in title or content or have ticket=NVDA. To train the word2vec
# -

# %% [markdown]
# # Modeling
#
# We have two approaches to choose from. We can use skip-gram or bag-of-words. The benefit of skip-gram is that it is better at semantics, but it is computationally more expensive than bag-of-words.

# %%
def
# Out:
#   Cell In[46], line 1
#     def
#         ^
# SyntaxError: invalid syntax
