# %% [markdown]
# # Bertopic with Kickstarter

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pyreadr
import os

# %% [markdown]
# # Load data

# %%
def get_pandas_frame(path):
    return pyreadr.read_r(path)[None]


def get_pandas_r_file(week_nr, file_type):
    week_nr = str(week_nr)
    week_folder = f"Kickstarter/2019_week{week_nr}"
    pledge_name = os.path.join(week_folder, f"{file_type}.rds")
    return get_pandas_frame(pledge_name)

def select_all_project_id_from_category(df, category):
    """
    take all the project id with the column Category == category
    :param df:
    :param category:
    :return:
    """
    df = df[df["Category"] == category]
    return df["my_id"].unique()

# %%
info_week_19 = get_pandas_r_file(19, "info")
info_week_19
# Out:
#                 my_id    creator_slug                            project_slug  \
# 0      project_000001      2146868994  the-because-black-life-conference-2018
# 1      project_000002      1805256969    petography-illustrations-of-your-pet
# 2      project_000003       352302209              dessert-cuties-enamel-pins
# 3      project_000004  melaniecollins         adorable-deadpool-chibi-sticker
# 4      project_000005        17929745             japanese-mythos-enamel-pins
# ...               ...             ...                                     ...
# 73795             NaN             NaN                                     NaN
# 73796             NaN             NaN                                     NaN
# 73797             NaN             NaN                                     NaN
# 73798             NaN             NaN                                     NaN
# 73799             NaN             NaN                                     NaN
#
#                                                    Blurb      Category  \
# 0      The Because Black Life Conference is a (Black)...           Art
# 1      Show an appreciation for your pet by having a ...  Illustration
# 2       Kawaii Style Enamel Pins featuring yummy treats!           Art
# 3      Help me get my Deadpool stickers printed and g...  Illustration
# 4      Enamel pins based on creatures from Japanese M...           Art
# ...                                                  ...           ...
# 73795                                                NaN           NaN
# 73796                                                NaN           NaN
# 73797                                                NaN           NaN
# 73798                                                NaN           NaN
# 73799                                                NaN           NaN
#
#                Location Staff_recommended   Goal_USD      Pledge_USD  \
# 0      Minneapolis | US              TRUE      10000           10150
# 1         Victoria | CA             FALSE  156.13997  645.0844790565
# 2           Boston | US             FALSE        800             815
# 3        Kettering | US             FALSE        400             870
# 4      Minneapolis | US             FALSE       1050           11069
# ...                 ...               ...        ...             ...
# 73795               NaN               NaN        NaN             NaN
# 73796               NaN               NaN        NaN             NaN
# 73797               NaN               NaN        NaN             NaN
# 73798               NaN               NaN        NaN             NaN
# 73799               NaN               NaN        NaN             NaN
#
#       Number_Backers  ...                    Project_Community_top_countries  \
# 0                 72  ...  |United States:57 backers|Australia:1 backer|S...
# 1                 34  ...  |United States:23 backers|Canada:2 backers|Uni...
# 2                 33  ...       |United States:24 backers|Australia:1 backer
# 3                 61  ...  |United States:49 backers|United Kingdom:5 bac...
# 4                293  ...  |United States:239 backers|Canada:11 backers|U...
# ...              ...  ...                                                ...
# 73795            NaN  ...                                                NaN
# 73796            NaN  ...                                                NaN
# 73797            NaN  ...                                                NaN
# 73798            NaN  ...                                                NaN
# 73799            NaN  ...                                                NaN
#
#       Project_Community_nb_new_backers Project_Community_nb_returning_backers  \
# 0                                   27                                     45
# 1                                    1                                     33
# 2                                    7                                     26
# 3                                    0                                     61
# 4                                    6                                    287
# ...                                ...                                    ...
# 73795                              NaN                                    NaN
# 73796                              NaN                                    NaN
# 73797                              NaN                                    NaN
# 73798                              NaN                                    NaN
# 73799                              NaN                                    NaN
#
#                                      Creator_description Creator_nb_projects  \
# 0      August 18th 10a-6pm Cultivated by www.BlackTab...                   1
# 1      As an entrepreneur at heart, I enjoy creativit...                   5
# 2      I am lover of all things cute and cuddly and i...                   2
# 3      My name is Melanie Collins (aka Melbaka) and I...                  10
# 4      I am very excited to create new projects. I ho...                   5
# ...                                                  ...                 ...
# 73795                                                NaN                 NaN
# 73796                                                NaN                 NaN
# 73797                                                NaN                 NaN
# 73798                                                NaN                 NaN
# 73799                                                NaN                 NaN
#
#              Creator_date_joined   Creator_nb_backed Creator_location  \
# 0      2018-04-04 18:17:30 -0400   Backed 0 projects               KO
# 1      2017-03-28 18:37:59 -0400   Backed 2 projects               KO
# 2      2017-08-12 17:05:11 -0400   Backed 6 projects       Boston, MA
# 3      2016-03-06 18:10:08 -0500   Backed 3 projects       Dayton, OH
# 4      2013-10-12 23:41:38 -0400  Backed 67 projects  Minneapolis, MN
# ...                          ...                 ...              ...
# 73795                        NaN                 NaN              NaN
# 73796                        NaN                 NaN              NaN
# 73797                        NaN                 NaN              NaN
# 73798                        NaN                 NaN              NaN
# 73799                        NaN                 NaN              NaN
#
#       Creator_made_comments                                Project_description
# 0                        KO  The Because Black Life Conference 2018 - This ...
# 1                        24  Risks and challenges  Having done print focuse...
# 2                         4  Who doesn't love cute enamel pins? I madeÂ sev...
# 3                         3  My name is Melanie (Melbaka) and welcome to my...
# 4                        42  â¦ï¸â¦ï¸â¦ï¸ Information â¦ï¸â¦ï¸â¦...
# ...                     ...                                                ...
# 73795                   NaN                                                NaN
# 73796                   NaN                                                NaN
# 73797                   NaN                                                NaN
# 73798                   NaN                                                NaN
# 73799                   NaN                                                NaN
#
# [73800 rows x 28 columns]

# %%
software_project_ids = select_all_project_id_from_category(info_week_19, "Software")
software_project_ids
# Out:
# array(['project_005539', 'project_005540', 'project_005541', ...,
#        'project_007598', 'project_007599', 'project_007600'], dtype=object)

# %%
posts_week_19 = get_pandas_r_file(19, "posts")
posts_week_19
# Out:
#          Project_my_id      creator_slug  \
# 0       project_000001        2146868994
# 1       project_000002        1805256969
# 2       project_000002        1805256969
# 3       project_000002        1805256969
# 4       project_000002        1805256969
# ...                ...               ...
# 446868  project_073361       rowanlakejr
# 446869  project_073361       rowanlakejr
# 446870  project_073361       rowanlakejr
# 446871  project_073361       rowanlakejr
# 446872  project_073365  babyplantdesigns
#
#                                   project_slug    Post_Nb  \
# 0       the-because-black-life-conference-2018  Update #1
# 1         petography-illustrations-of-your-pet  Update #5
# 2         petography-illustrations-of-your-pet  Update #4
# 3         petography-illustrations-of-your-pet  Update #3
# 4         petography-illustrations-of-your-pet  Update #2
# ...                                        ...        ...
# 446868                           new-altervice  Update #4
# 446869                           new-altervice  Update #3
# 446870                           new-altervice  Update #2
# 446871                           new-altervice  Update #1
# 446872                      baby-plant-designs  Update #1
#
#                                     Post_Title     Post_Date  \
# 0       Can you believe it!! 8 Endorsements!!!  May 18, 2018
# 1               Petography End of July Update!  Jul 24, 2018
# 2                              Digital Update!  Jul 11, 2018
# 3                           Petography Update!  Jun 13, 2018
# 4                           Name of your pets!  May 22, 2018
# ...                                        ...           ...
# 446868                           A Bit of Info  Mar 14, 2019
# 446869                Altervice Website Part 2  Mar 11, 2019
# 446870                       Altervice Website   Mar 5, 2019
# 446871                New Altervice Commercial   Mar 1, 2019
# 446872         Supporting Bee Organizations!!!   Apr 3, 2019
#
#                                                 Post_Text          Post_id
# 0       The Because Black Life Conference is a (Black)...  project_0000011
# 1       Hi everyone!  Hope your summer is going well! ...  project_0000025
# 2                                        ONLY FOR BACKERS  project_0000024
# 3                                        ONLY FOR BACKERS  project_0000023
# 4                                        ONLY FOR BACKERS  project_0000022
# ...                                                   ...              ...
# 446868  Just in case you never saw what the larger siz...  project_0733614
# 446869  The Altervice website is almost complete. I've...  project_0733613
# 446870  That's right folks! I'm currently working on a...  project_0733612
# 446871  Hey guys! Thanks so much for support! Here's a...  project_0733611
# 446872  With being a organic friendly company, with th...  project_0733651
#
# [446873 rows x 8 columns]

# %% [markdown]
# # Now we select only the posts from the projects that are in the category software

# %%
def select_posts_from_the_available_project_ids(posts_df, project_ids):
    """
    select all the posts from the project ids
    :param posts_df:
    :param project_ids:
    :return:
    """
    return posts_df[posts_df["Project_my_id"].isin(project_ids)]

# %%
posts_software_projects = select_posts_from_the_available_project_ids(posts_week_19, software_project_ids)
posts_software_projects
# Out:
#         Project_my_id creator_slug  \
# 38385  project_005539   damicareer
# 38386  project_005539   damicareer
# 38387  project_005546    kidunot89
# 38388  project_005547    465222059
# 38389  project_005547    465222059
# ...               ...          ...
# 43378  project_007590    102287676
# 43379  project_007592   1224571211
# 43380  project_007592   1224571211
# 43381  project_007595      croosle
# 43382  project_007595      croosle
#
#                                             project_slug    Post_Nb  \
# 38385                                    purpose-connect  Update #2
# 38386                                    purpose-connect  Update #1
# 38387                              wpgraphql-woocommerce  Update #1
# 38388                                   table-university  Update #2
# 38389                                   table-university  Update #1
# ...                                                  ...        ...
# 43378     the-hangupmachine-a-spam-filter-for-your-phone  Update #1
# 43379    research-assistant-tools-to-accelerate-research  Update #2
# 43380    research-assistant-tools-to-accelerate-research  Update #1
# 43381  croosle-all-in-one-educational-and-experimenta...  Update #2
# 43382  croosle-all-in-one-educational-and-experimenta...  Update #1
#
#                                               Post_Title     Post_Date  \
# 38385                                         The WHY...  Apr 23, 2019
# 38386               Timeline Expectations - Day 2 Update  Apr 20, 2019
# 38387                                Release v0.0.3-beta  Apr 25, 2019
# 38388                          new collaboration started   Apr 9, 2019
# 38389                            additional information!   Apr 5, 2019
# ...                                                  ...           ...
# 43378                                     Half way point   May 5, 2014
# 43379  We can now search the Public Library of Scienc...  Apr 25, 2014
# 43380                  First suggestion and a great one!  Apr 21, 2014
# 43381               Croosle Smart Kit - stay up-to-date!  May 12, 2014
# 43382               Croosle Smart Kit with new features!  Apr 21, 2014
#
#                                                Post_Text          Post_id
# 38385  I received this from one of my clients last ye...  project_0055392
# 38386  Hey guys, itâs Day 2 and I just want to firs...  project_0055391
# 38387  Version 0.0.3   was released.   Full Changelog...  project_0055461
# 38388  We started a new collaboration with tesilike. ...  project_0055472
# 38389  Hi all!  I would add just an information to be...  project_0055471
# ...                                                  ...              ...
# 43378                                   ONLY FOR BACKERS  project_0075901
# 43379  Research Assistant R502 is now available, maki...  project_0075922
# 43380  Many thanks to everyone who have shown interes...  project_0075921
# 43381                                   ONLY FOR BACKERS  project_0075952
# 43382                                   ONLY FOR BACKERS  project_0075951
#
# [4994 rows x 8 columns]

# %%
animation_projects = select_all_project_id_from_category(info_week_19, "Animation")
posts_animation_projects = select_posts_from_the_available_project_ids(posts_week_19, animation_projects)
posts_animation_projects
# Out:
#          Project_my_id  creator_slug  \
# 141480  project_022394   ivanricardi
# 141481  project_022394   ivanricardi
# 141482  project_022396        katina
# 141499  project_022424    1209343473
# 141500  project_022424    1209343473
# ...                ...           ...
# 292258  project_050242         doejo
# 292259  project_050242         doejo
# 292260  project_050242         doejo
# 292261  project_050246  twointhepink
# 292262  project_050247           cab
#
#                                              project_slug    Post_Nb  \
# 141480  creation-of-the-official-animated-video-clip-p...  Update #2
# 141481  creation-of-the-official-animated-video-clip-p...  Update #1
# 141482  make-krushia-story-an-animated-movie-to-promot...  Update #1
# 141499                                            fleegix  Update #2
# 141500                                            fleegix  Update #1
# ...                                                   ...        ...
# 292258                                       homeless-cop  Update #3
# 292259                                       homeless-cop  Update #2
# 292260                                       homeless-cop  Update #1
# 292261                          music-video-for-reso-morn  Update #1
# 292262                              cab-international-inc  Update #1
#
#                                                Post_Title     Post_Date  \
# 141480  gracias por tu apoyo, hoy despertamos optimist...  Apr 25, 2019
# 141481           preparing the letter to plan the project  Apr 24, 2019
# 141482  I launched my campaign several days ago and I ...  Apr 29, 2019
# 141499                Alan Mendelsohn, The Boy From Mars.  Apr 25, 2019
# 141500                               DAY 1: HOLY COW!!!!!  Apr 23, 2019
# ...                                                   ...           ...
# 292258                                  Kato watching TV!   Sep 3, 2011
# 292259                                  Kato gets a job?!  Aug 26, 2011
# 292260                                  Nelson &amp; Kato  Aug 12, 2011
# 292261                                         new video!   Aug 6, 2011
# 292262                               Celebrities On Board  Jul 20, 2011
#
#                                                 Post_Text          Post_id
# 141480  gracias por tu apoyo, hoy despertamos optimist...  project_0223942
# 141481  With much emotion I share that we are preparin...  project_0223941
# 141482  I currently have Sharp Eye Animation Company w...  project_0223961
# 141499  #fleegix is an adaptation of this book by Dani...  project_0224242
# 141500  Almost a third of the way funded on the first ...  project_0224241
# ...                                                   ...              ...
# 292258              Someday he will see himself on there!  project_0502423
# 292259  Imagine the cool cat we all know as Kato, if h...  project_0502422
# 292260  Just 2 good friends in a show about,........st...  project_0502421
# 292261        We've uploaded a new video--check it out!Â   project_0502461
# 292262  We have Money B from Digital Underground and n...  project_0502471
#
# [7674 rows x 8 columns]

# %%
videogames_projects = select_all_project_id_from_category(info_week_19, "Video Games")
posts_videogames_projects = select_posts_from_the_available_project_ids(posts_week_19, videogames_projects)
posts_videogames_projects
# Out:
#          Project_my_id   creator_slug  \
# 149664  project_024250      220356443
# 149665  project_024250      220356443
# 149666  project_024250      220356443
# 149667  project_024250      220356443
# 149668  project_024251      125520822
# ...                ...            ...
# 377750  project_058917     2079547763
# 446816  project_073338  timseastudios
# 446817  project_073338  timseastudios
# 446818  project_073338  timseastudios
# 446819  project_073338  timseastudios
#
#                                              project_slug     Post_Nb  \
# 149664                    corruption-a-history-of-lestive   Update #4
# 149665                    corruption-a-history-of-lestive   Update #3
# 149666                    corruption-a-history-of-lestive   Update #2
# 149667                    corruption-a-history-of-lestive   Update #1
# 149668                  romance-divine-adult-visual-novel   Update #3
# ...                                                   ...         ...
# 377750                          jagged-alliance-flashback  Update #36
# 446816  adome-action-platformer-and-exploration-adventure   Update #4
# 446817  adome-action-platformer-and-exploration-adventure   Update #3
# 446818  adome-action-platformer-and-exploration-adventure   Update #2
# 446819  adome-action-platformer-and-exploration-adventure   Update #1
#
#                                                Post_Title     Post_Date  \
# 149664                         Novelisation of Corruption  Apr 29, 2019
# 149665  Races in Corruption (and the rest of the Thorn...  Apr 28, 2019
# 149666  The History of the Thorntop World (or why I ma...  Apr 27, 2019
# 149667                                     Awesome Start!  Apr 27, 2019
# 149668                            100 backers, 20% there!   May 1, 2019
# ...                                                   ...           ...
# 377750         Developer Diary 1 on Character Development  Nov 15, 2013
# 446816                       Timsea Studios announcement.  Apr 26, 2019
# 446817                   Working the art of displacement!  Apr 22, 2019
# 446818                                          Gameplay!  Apr 18, 2019
# 446819  Adome: Aventura de acciÃ³n, plataformas y expl...  Apr 16, 2019
#
#                                                 Post_Text           Post_id
# 149664  Hey all, as you all know the Level 5 reward ti...   project_0242504
# 149665  Hey all. I said I would discuss race in the ga...   project_0242503
# 149666  I mentioned briefly in my main post about how ...   project_0242502
# 149667  Thank you so much for the pledges so far. We'v...   project_0242501
# 149668  Special update to commemorate getting our 100t...   project_0242513
# ...                                                   ...               ...
# 377750  Dear Backers,  Today we have a real treat for ...  project_05891736
# 446816  In Timsea Studios we have made the decision to...   project_0733384
# 446817  In Timsea Studios we are paying special attent...   project_0733383
# 446818  Adome gameplay is based on a satisfying sense ...   project_0733382
# 446819  ADOME es una aventura de acciÃ³n, plataformas ...   project_0733381
#
# [28285 rows x 8 columns]

# %% [markdown]
# # Bertopic

# %% [markdown]
# # Method 1 where you specify each building block

# %%
from umap import UMAP
from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer

from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from bertopic.vectorizers import ClassTfidfTransformer

def get_standard_bertopic():
    # Step 1 - Extract embeddings
    embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

    # Step 2 - Reduce dimensionality
    umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine')

    # Step 3 - Cluster reduced embeddings
    hdbscan_model = HDBSCAN(min_cluster_size=15, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

    # Step 4 - Tokenize topics
    vectorizer_model = CountVectorizer(stop_words="english")

    # Step 5 - Create topic representation
    ctfidf_model = ClassTfidfTransformer()

    # Step 6 - (Optional) Fine-tune topic representations with
    # a `bertopic.representation` model
    representation_model = KeyBERTInspired()

    # All steps together
    topic_model = BERTopic(
      embedding_model=embedding_model,          # Step 1 - Extract embeddings
      umap_model=umap_model,                    # Step 2 - Reduce dimensionality
      hdbscan_model=hdbscan_model,              # Step 3 - Cluster reduced embeddings
      vectorizer_model=vectorizer_model,        # Step 4 - Tokenize topics
      ctfidf_model=ctfidf_model,                # Step 5 - Extract topic words
      representation_model=representation_model # Step 6 - (Optional) Fine-tune topic represenations
    )
    return topic_model

# %% [markdown]
# ## make a topic model for software

# %%
topic_model_software = get_standard_bertopic()
topics_software, probs_software = topic_model_software.fit_transform(posts_software_projects["Post_Text"])

# %%
topic_model_software.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   1803           -1_kickstarter_development_design_create
# 1       0    733                      0_backers_sports_cordor_ducor
# 2       1    336               1_funding_funded_pledged_kickstarter
# 3       2    208              2_kickstarter_funding_funded_projects
# 4       3    173                    3_beta_releases_release_updates
# 5       4    165                             4_ios_apps_android_app
# 6       5    143                 5_chapters_ebook_chapter_paperback
# 7       6    135                                      6_ko_kristy__
# 8       7    117                     7_xiki_xsh_kickstarter_surveys
# 9       8     62                  8_moviesandbox_vimeo_films_videos
# 10      9     52                        9_como_proyecto_acceso_pero
# 11     10     51                               10_usb_disks_disk_sd
# 12     11     49                      11_ios_swift_kickstarter_ipad
# 13     12     48           12_courses_django_kickstarter_codecademy
# 14     13     47                     13_icons_font_kickstarter_icon
# 15     14     47                                             14____
# 16     15     42                  15_gideros_git_github_kickstarter
# 17     16     40       16_music_promote_musicgateway_accompanymusic
# 18     17     38      17_programming_interactive_program_programmed
# 19     18     37                   18_p3d_flyinside_prepar3d_oculus
# 20     19     37             19_privly_kickstarter_priv_privlyalpha
# 21     20     36          20_translations_lang_translated_languages
# 22     21     35       21_openshot_keyframes_animation_improvements
# 23     22     34             22_java_programming_languages_language
# 24     23     29               23_courses_projects_learning_lessons
# 25     24     28      24_curriculums_curriculum_courses_kickstarter
# 26     25     28         25_healthcare_patients_medicine_physicians
# 27     26     27                        26_replay_sound_html5_video
# 28     27     26                 27_beescanning_app_beekeeping_bees
# 29     28     24               28_cameleon_streaming_stream_android
# 30     29     24                      29_replay_html5_browser_sound
# 31     30     24   30_android_learnandroidcomplete_apps_kickstarter
# 32     31     22                 31_plots_graphs_graphics_computing
# 33     32     21                             32_h264_h265_vpu_mpeg2
# 34     33     21               33_templates_template_layout_designs
# 35     34     20               34_kangasound_bars_percussion_kangas
# 36     35     19             35_saiku_kickstarter_funding_donations
# 37     36     19               36_tutorials_easywaysql_database_sql
# 38     37     19                      37_replay_html5_browser_sound
# 39     38     19          38_emoji_emojidex_gemoji_phantomopenemoji
# 40     39     18  39_kickstarter_mybooktable_kickstarters_mybook...
# 41     40     18               40_numlockapp_numlock_num_numcommand
# 42     41     18                      41_vlc_msvcrt_winrt_microsoft
# 43     42     18          42_kickstarter_twitterrific_ollie_updates
# 44     43     18          43_homework_expanded_expanding_adjectives
# 45     44     17                   44_dmedia_couchdb_gstreamer_sync
# 46     45     17                       45_krita_krita_x64_2_kde_osx
# 47     46     16          46_lighttable_table_light_tableuniversity
# 48     47     16  47_minibloq_minibloqv081beta_minisim_translations
#
#                                        Representation  \
# 0   [kickstarter, development, design, create, sof...
# 1        [backers, sports, cordor, ducor, , , , , , ]
# 2   [funding, funded, pledged, kickstarter, donate...
# 3   [kickstarter, funding, funded, projects, succe...
# 4   [beta, releases, release, updates, upcoming, i...
# 5   [ios, apps, android, app, appstore, mobile, ip...
# 6   [chapters, ebook, chapter, paperback, books, b...
# 7                        [ko, kristy, , , , , , , , ]
# 8   [xiki, xsh, kickstarter, surveys, coming, surv...
# 9   [moviesandbox, vimeo, films, videos, movieslic...
# 10  [como, proyecto, acceso, pero, tenemos, aprend...
# 11  [usb, disks, disk, sd, flash, card, shipping, ...
# 12  [ios, swift, kickstarter, ipad, apps, iphone, ...
# 13  [courses, django, kickstarter, codecademy, pyt...
# 14  [icons, font, kickstarter, icon, fontawesome, ...
# 15                               [, , , , , , , , , ]
# 16  [gideros, git, github, kickstarter, apps, os, ...
# 17  [music, promote, musicgateway, accompanymusic,...
# 18  [programming, interactive, program, programmed...
# 19  [p3d, flyinside, prepar3d, oculus, leap, flyin...
# 20  [privly, kickstarter, priv, privlyalpha, priva...
# 21  [translations, lang, translated, languages, tr...
# 22  [openshot, keyframes, animation, improvements,...
# 23  [java, programming, languages, language, cloju...
# 24  [courses, projects, learning, lessons, funding...
# 25  [curriculums, curriculum, courses, kickstarter...
# 26  [healthcare, patients, medicine, physicians, d...
# 27  [replay, sound, html5, video, play, browser, l...
# 28  [beescanning, app, beekeeping, bees, google, s...
# 29  [cameleon, streaming, stream, android, youtube...
# 30  [replay, html5, browser, sound, youtube, play,...
# 31  [android, learnandroidcomplete, apps, kickstar...
# 32  [plots, graphs, graphics, computing, protocols...
# 33  [h264, h265, vpu, mpeg2, allwinner, decoded, d...
# 34  [templates, template, layout, designs, theme, ...
# 35  [kangasound, bars, percussion, kangas, soundfi...
# 36  [saiku, kickstarter, funding, donations, spons...
# 37  [tutorials, easywaysql, database, sql, mysql, ...
# 38  [replay, html5, browser, sound, youtube, play,...
# 39  [emoji, emojidex, gemoji, phantomopenemoji, sv...
# 40  [kickstarter, mybooktable, kickstarters, myboo...
# 41  [numlockapp, numlock, num, numcommand, nag, me...
# 42  [vlc, msvcrt, winrt, microsoft, webgl, libvlc,...
# 43  [kickstarter, twitterrific, ollie, updates, fu...
# 44  [homework, expanded, expanding, adjectives, te...
# 45  [dmedia, couchdb, gstreamer, sync, novacut, re...
# 46  [krita, krita_x64_2, kde, osx, kiki, files, do...
# 47  [lighttable, table, light, tableuniversity, hi...
# 48  [minibloq, minibloqv081beta, minisim, translat...
#
#                                   Representative_Docs
# 0   [With only  8 days left  till the end of the c...
# 1   [ONLY FOR BACKERS, ONLY FOR BACKERS, ONLY FOR ...
# 2   [Hey guys, itâs Day 2 and I just want to fir...
# 3   [All,  When we started our Kickstarter, we tho...
# 4   [Just one week to go before our beta 1 release...
# 5   [Long time no talk! Sorry we haven't posted an...
# 6   [Hi,  I just wanted to let everyone know that ...
# 7                                        [KO, KO, KO]
# 8   [Hi all. Thanks again for your awesome support...
# 9   [Dear Kickstarters,   Moviesandbox Version 1.0...
# 10  [â  Â¿Quieres perder peso? Â¿Mejorar tu form...
# 11  [Dear backers!  The USB flash disks have final...
# 12  [Our 50% off MAGE and iOS tutorials sale conti...
# 13  [Hi All,  First off, thanks so much for all yo...
# 14  [Dear Awesome Backers,  Wow...Just wow. Thanks...
# 15                                             [, , ]
# 16  [We areÂ delighted to announce that, as of ver...
# 17  [Another day, another backer - Welcome to all ...
# 18  [Hello there!  Two very special guests visited...
# 19  [FlyInside Beta #1 Coming Soon!   The very fir...
# 20  [Privly Backers,  Long time no update! We have...
# 21  [Hello Backers,  We think the Summary idea fro...
# 22  [I am proud to announce the release of  OpenSh...
# 23  [Localizing the World, Starting With Localized...
# 24  [Just wanted to update everyone. I am still wo...
# 25  [We're incredibly excited to the announce our ...
# 26  [Dear Kickstarter Backers,  Most of us have he...
# 27  [You may be able to win the next one! Get invo...
# 28  [Become part of BeeScanning development - righ...
# 29  [Cameleon 2.0 LIVE, âÂ We are happy to annou...
# 30  [You'll need an HTML5 capable browser to see t...
# 31  [Hello everyone!It was exactly 2 years ago tod...
# 32  [Apparent progress has accelerated, because th...
# 33  [Yet another week, yet another update. Last we...
# 34  [We have just added 40 new templates. These te...
# 35  [I have added another five more bars to the so...
# 36  [Hi Folks  Apologies for the radio silence ove...
# 37  [Hi guys, Â How have you been?Â   Â I wanted t...
# 38  [You'll need an HTML5 capable browser to see t...
# 39  [We've doubled what we'll make from the $10k s...
# 40  [Kickstarter,  What an amazing day!Â   We have...
# 41  [I created a screen in the NumLock app display...
# 42  [Emscripten  is a fantastic project to cross-c...
# 43  [After Ollie spotted his new discovery, he was...
# 44  [summer of Blender    Â      water    Â      S...
# 45  [I'm pleased to unveil the secure device peeri...
# 46  [The second beta of Krita 2.9 is out! Lots and...
# 47  [Hey Everyone,  I'm proud to announce that as ...
# 48  [Hi! The next version of Minibloq is near, and...

# %%
topic_model_software.get_topic(0)
# Out:
# [('backers', 0.7565515),
#  ('sports', 0.22999015),
#  ('cordor', 0.21286517),
#  ('ducor', 0.20531508),
#  ('', 0.19963846),
#  ('', 0.19963846),
#  ('', 0.19963846),
#  ('', 0.19963846),
#  ('', 0.19963846),
#  ('', 0.19963846)]

# %%
topic_model_software.visualize_topics()
# Out:
# <div>                            <div id="c5ab282a-c100-4739-a77f-aade0e28c0c3" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5ab282a-c100-4739-a77f-aade0e28c0c3")) {                    Plotly.newPlot(                        "c5ab282a-c100-4739-a77f-aade0e28c0c3",                        [{"customdata":[[0,"backers | sports | cordor | ducor | ",733],[1,"funding | funded | pledged | kickstarter | donate",336],[2,"kickstarter | funding | funded | projects | successful",208],[3,"beta | releases | release | updates | upcoming",173],[4,"ios | apps | android | app | appstore",165],[5,"chapters | ebook | chapter | paperback | books",143],[6,"ko | kristy |  |  | ",135],[7,"xiki | xsh | kickstarter | surveys | coming",117],[8,"moviesandbox | vimeo | films | videos | movieslice",62],[9,"como | proyecto | acceso | pero | tenemos",52],[10,"usb | disks | disk | sd | flash",51],[11,"ios | swift | kickstarter | ipad | apps",49],[12,"courses | django | kickstarter | codecademy | python",48],[13,"icons | font | kickstarter | icon | fontawesome",47],[14," |  |  |  | ",47],[15,"gideros | git | github | kickstarter | apps",42],[16,"music | promote | musicgateway | accompanymusic | songs",40],[17,"programming | interactive | program | programmed | classroom",38],[18,"p3d | flyinside | prepar3d | oculus | leap",37],[19,"privly | kickstarter | priv | privlyalpha | privacy",37],[20,"translations | lang | translated | languages | translate",36],[21,"openshot | keyframes | animation | improvements | keyframe",35],[22,"java | programming | languages | language | clojure",34],[23,"courses | projects | learning | lessons | funding",29],[24,"curriculums | curriculum | courses | kickstarter | educational",28],[25,"healthcare | patients | medicine | physicians | doctors",28],[26,"replay | sound | html5 | video | play",27],[27,"beescanning | app | beekeeping | bees | google",26],[28,"cameleon | streaming | stream | android | youtube",24],[29,"replay | html5 | browser | sound | youtube",24],[30,"android | learnandroidcomplete | apps | kickstarter | development",24],[31,"plots | graphs | graphics | computing | protocols",22],[32,"h264 | h265 | vpu | mpeg2 | allwinner",21],[33,"templates | template | layout | designs | theme",21],[34,"kangasound | bars | percussion | kangas | soundfiles",20],[35,"saiku | kickstarter | funding | donations | sponsorship",19],[36,"tutorials | easywaysql | database | sql | mysql",19],[37,"replay | html5 | browser | sound | youtube",19],[38,"emoji | emojidex | gemoji | phantomopenemoji | svg",19],[39,"kickstarter | mybooktable | kickstarters | mybookprogress | bestseller",18],[40,"numlockapp | numlock | num | numcommand | nag",18],[41,"vlc | msvcrt | winrt | microsoft | webgl",18],[42,"kickstarter | twitterrific | ollie | updates | funded",18],[43,"homework | expanded | expanding | adjectives | terms\u00e2",18],[44,"dmedia | couchdb | gstreamer | sync | novacut",17],[45,"krita | krita_x64_2 | kde | osx | kiki",17],[46,"lighttable | table | light | tableuniversity | highlights",16],[47,"minibloq | minibloqv081beta | minisim | translations | documentation",16]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[733,336,208,173,165,143,135,117,62,52,51,49,48,47,47,42,40,38,37,37,36,35,34,29,28,28,27,26,24,24,24,22,21,21,20,19,19,19,19,18,18,18,18,18,17,17,16,16],"sizemode":"area","sizeref":0.458125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18.31969451904297,17.739395141601562,18.455488204956055,-4.530259609222412,-4.093321800231934,10.061701774597168,18.522197723388672,18.1 ...

# %%
topic_model_software.visualize_barchart(top_n_topics=32)
# Out:
# <div>                            <div id="f8ce7fe3-382c-4653-9b63-6db9eb8b091c" class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8ce7fe3-382c-4653-9b63-6db9eb8b091c")) {                    Plotly.newPlot(                        "f8ce7fe3-382c-4653-9b63-6db9eb8b091c",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.1996384561061859,0.20531508326530457,0.2128651738166809,0.229990154504776,0.7565515041351318],"y":["  ","ducor  ","cordor  ","sports  ","backers  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.40673890709877014,0.43275347352027893,0.4336404800415039,0.4446702003479004,0.47808775305747986],"y":["donate  ","kickstarter  ","pledged  ","funded  ","funding  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.3024916648864746,0.34494489431381226,0.3931354284286499,0.42331716418266296,0.6510075330734253],"y":["successful  ","projects  ","funded  ","funding  ","kickstarter  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.38201212882995605,0.41335099935531616,0.4226832389831543,0.44657206535339355,0.5028315186500549],"y":["upcoming  ","updates  ","release  ","releases  ","beta  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.41700658202171326,0.44807010889053345,0.459999144077301,0.48456406593322754,0.4877813458442688],"y":["appstore  ","app  ","android  ","apps  ","ios  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.34452903270721436,0.4123881757259369,0.4183312952518463,0.48401781916618347,0.5281385183334351],"y":["books  ","paperback  ","chapter  ","ebook  ","chapters  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.35646694898605347,0.35646694898605347,0.35646694898605347,0.3820464611053467,1.0],"y":["  ","  ","  ","kristy  ","ko  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.20256823301315308,0.22835780680179596,0.2577638328075409,0.3879038691520691,0.7007678151130676],"y":["coming  ","surveys  ","kickstarter  ","xsh  ","xiki  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.40610629320144653,0.41471895575523376,0.4204961061477661,0.4559038281440735,0.5916318893432617],"y":["movieslice  ","videos  ","films  ","vimeo  ","moviesandbox  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.36588966846466064,0.3759916126728058,0.38644832372665405,0.3921409249305725,0.41789817810058594],"y":["tenemos  ","pero  ","acceso  ","proyecto  ","como  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.30637431144714355,0.3094700574874878,0.3519933819770813,0.3807254731655121,0.4089479148387909],"y":["flash  ","sd  ","disk  ","disks  ","usb  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.3830883502960205,0.4027855098247528,0.42223429679870605,0.43143701553344727,0.4646373689174652],"y":["apps  ","ipad  ","kickstarter  ","swift  ","ios  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.356164813041687,0.418520450592041,0.4466238021850586,0.4492042362689972,0.4539109468460083],"y":["python  ","codecademy  ","kickstarter  ","django  ","courses  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.3763653635978699,0.3862766623497009,0.3877836763858795,0.3978702425956726,0.5050987601280212],"y":["fontawesome  ","icon  ","kickstarter  ","font  ", ...

# %% [markdown]
# ## make a topic model for animation

# %%
topic_model_animation = get_standard_bertopic()
topics_animation, probs_animation = topic_model_animation.fit_transform(posts_animation_projects["Post_Text"])

# %%
topic_model_animation.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   3233              -1_kickstarter_making_production_work
# 1       0   1509                        0_backers_backer_promotion_
# 2       1    225                  1_pledge_pledges_pledged_pledging
# 3       2    195                   2_festival_fest_festivals_cinema
# 4       3    178                          3_replay_html5_sound_play
# 5       4    155         4_donated_donations_donation_contributions
# 6       5    144                                              5____
# 7       6    141                                            6_ko___
# 8       7    125                         7_film_vimeo_trailer_movie
# 9       8    124                          8_sky_puppets_film_ghosts
# 10      9    123                 9_shipping_shipments_shipment_ship
# 11     10    105                       10_dai_chuya_shogun_sasahara
# 12     11     89            11_surveys_kickstarter_backerkit_survey
# 13     12     83                       12_voiced_voice_actor_voices
# 14     13     63                 13_backers_backer_backings_support
# 15     14     63          14_kickstarter_episodes_episodesâ_episode
# 16     15     58                   15_musical_soundtrack_music_film
# 17     16     56                      16_esto_dejamos_como_realidad
# 18     17     54            17_kickstarter_campaign_funding_pledged
# 19     18     51                                           18_ko___
# 20     19     49     19_storyboards_storyboard_animations_animation
# 21     20     48                      20_replay_html5_browser_sound
# 22     21     48                        21_shirts_shirt_apparel_tee
# 23     22     47           22_animation_animated_artwork_characters
# 24     23     46            23_kickstarter_funding_campaign_trailer
# 25     24     41                  24_morph_morphâ_merlin_adventures
# 26     25     41                      25_replay_html5_browser_sound
# 27     26     40                 26_footage_scenes_animation_frames
# 28     27     33                  27_caretaker_sheriff_mantu_arbutt
# 29     28     31                                28_une_pas_vie_bien
# 30     29     31                            29_dogâ_dogã_yuri_yuriã
# 31     30     29   30_kickstarter_kickstartasos_animation_premiered
# 32     31     28           31_animate_characters_inspirationâ_scene
# 33     32     27                  32_pledges_pledge_pledged_pledgeâ
# 34     33     26               33_bendito_benditos_todo_kickstarter
# 35     34     26                       34_raise_000_generous_dollar
# 36     35     24           35_cartoons_cartoon_cartoonist_animation
# 37     36     23                     36_cast_movie_characters_jerry
# 38     37     23              37_rexfactor_rex_dinosaur_kickstarter
# 39     38     21  38_coffeeunicorn_coffee_ninjanarwhalcoffeeco_n...
# 40     39     20                   39_video_uploaded_videos_youtube
# 41     40     19        40_ifmu8ro_phu_mcsteedinc_youtu_7avxcdug1ng
# 42     41     19                 41_engraving_printed_prints_poster
# 43     42     19  42_kickstarter_kickstarttheweirdkidz_kickstart...
# 44     43     19                     43_park_indiegogo_studios_film
# 45     44     19                  44_loved_support_grateful_helping
# 46     45     18                         45_replay_es_spanish_html5
# 47     46     18                         46_dvd_dvds_vimeo_premiere
# 48     47     17                    47_postcards_gifts_rewards_swag
# 49     48     17  48_footage_thelittlepainterfilm_animation_anim...
# 50     49     17          49_neuroscience_imaging_cortex_microscope
# 51     50     16                   50_meow_plushies_meowyoga2_meows
#
#                                        Representation  \
# 0   [kickstarter, making, production, work, update...
# 1          [backers, backer, promotion, , , , , , , ]
# 2   [pledge, pledges, pledged, pledging, kickstart...
# 3   [festival, fest, festivals, cinema, cannes, sc...
# 4   [replay, html5, sound, play, browser, enjoy, v...
# 5   [donated, donations, donation, contributions, ...
# 6                                [, , , , , , , , , ]
# 7                              [ko, , , , , , , , , ]
# 8   [film, vimeo, trailer, movie, donated, progres...
# 9   [sky, puppets, film, ghosts, monster, films, p...
# 10  [shipping, shipments, shipment, ship, arrive, ...
# 11  [dai, chuya, shogun, sasahara, samurai, chika,...
# 12  [surveys, kickstarter, backerkit, survey, spam...
# 13  [voiced, voice, actor, voices, actors, acting,...
# 14  [backers, backer, backings, support, campaign,...
# 15  [kickstarter, episodes, episodesâ, episode, vi...
# 16  [musical, soundtrack, music, film, sound, audi...
# 17  [esto, dejamos, como, realidad, gracias, tenem...
# 18  [kickstarter, campaign, funding, pledged, fund...
# 19                             [ko, , , , , , , , , ]
# 20  [storyboards, storyboard, animations, animatio...
# 21  [replay, html5, browser, sound, youtube, play,...
# 22  [shirts, shirt, apparel, tee, kickstarter, pri...
# 23  [animation, animated, artwork, characters, des...
# 24  [kickstarter, funding, campaign, trailer, teas...
# 25  [morph, morphâ, merlin, adventures, peter, epi...
# 26  [replay, html5, browser, sound, play, video, s...
# 27  [footage, scenes, animation, frames, film, ani...
# 28    [caretaker, sheriff, mantu, arbutt, , , , , , ]
# 29  [une, pas, vie, bien, votre, les, le, dans, de...
# 30  [dogâ, dogã, yuri, yuriã, dog, reward, japanes...
# 31  [kickstarter, kickstartasos, animation, premie...
# 32  [animate, characters, inspirationâ, scene, ins...
# 33  [pledges, pledge, pledged, pledgeâ, rewards, r...
# 34  [bendito, benditos, todo, kickstarter, zumbaka...
# 35  [raise, 000, generous, dollar, dollars, 20k, 5...
# 36  [cartoons, cartoon, cartoonist, animation, bun...
# 37  [cast, movie, characters, jerry, lord, dialogu...
# 38  [rexfactor, rex, dinosaur, kickstarter, funded...
# 39  [coffeeunicorn, coffee, ninjanarwhalcoffeeco, ...
# 40  [video, uploaded, videos, youtube, posted, vim...
# 41  [ifmu8ro_phu, mcsteedinc, youtu, 7avxcdug1ng, ...
# 42  [engraving, printed, prints, poster, printing,...
# 43  [kickstarter, kickstarttheweirdkidz, kickstart...
# 44  [park, indiegogo, studios, film, tale, trailer...
# 45  [loved, support, grateful, helping, love, stay...
# 46  [replay, es, spanish, html5, gracias, como, to...
# 47  [dvd, dvds, vimeo, premiere, download, sketchb...
# 48  [postcards, gifts, rewards, swag, cards, rewar...
# 49  [footage, thelittlepainterfilm, animation, ani...
# 50  [neuroscience, imaging, cortex, microscope, ne...
# 51  [meow, plushies, meowyoga2, meows, plush, toys...
#
#                                   Representative_Docs
# 0   [Hello everyone! We're very sorry about the sl...
# 1   [ONLY FOR BACKERS, ONLY FOR BACKERS, ONLY FOR ...
# 2   [Hey p:13 backers !  project:13 needs a miracl...
# 3   [Happy December!  It's been a little over a mo...
# 4   [4 days to go! Still on time to choose your fa...
# 5   [Thank you to everyone so far for helping us g...
# 6                                         [, , cool!]
# 7                                        [KO, KO, KO]
# 8   [Hi there.  We are officially half way through...
# 9   [Hello dear backers! Â It's been a crazy, but ...
# 10  [Authoring Update   I got a set of test discs ...
# 11  [Hello Everyone,Â    Two new rewards have just...
# 12  [Dear Backers!  We wanted to make sure to do a...
# 13  [Greetings Kickstarters! \r We had our Automat...
# 14  [I want to give a big THANK YOU shout out to o...
# 15  [For the past 2 weeks backers have been able t...
# 16  [Hey all -Â   My apologies for the radio silen...
# 17  [English below   Hola a todos! Disculpen nuest...
# 18  [Happy Anniversary!!!       Wow that last year...
# 19                                       [KO, KO, KO]
# 20  [So weâre coming up to half way through the ...
# 21  [You'll need an HTML5 capable browser to see t...
# 22  [HAPPY NEW YEAR EVERYONE!!   We hope your wint...
# 23  [æ¥æ¬èªæé¢ã¯ä¸è¨ã«è¨è¼ãã¦ãã¾...
# 24  [We did it everyone! Together we managed to pu...
# 25  [Happy Friday, Morph Crew!  What better way to...
# 26  [You'll need an HTML5 capable browser to see t...
# 27  [Hello there! There is two weeks left in the K...
# 28  [The Caretaker, Sheriff Arbutt    Â , Mantu   ...
# 29  [Jusque lÃ , Nick, Rode et Jazz Jr. mÃ¨nent un...
# 30  [(æ¥æ¬èªã¯è±èªã®å¾ã«ç¶ãã¾ãã/J...
# 31  [You supported the 17th Annual Animation of Sh...
# 32  [This photo is still processing  Check back in...
# 33  [It all ends TONIGHT at 6:45PM EST.    So if y...
# 34  [CLICK IN THE FOLLOWING LINK FOR THE CURRENT C...
# 35  [Holy Cow! We made it past 20K today! What a w...
# 36  [What is it?   Cartoon Hype is a project I sta...
# 37  [The gunshot whipcrack of a Caddy door slammin...
# 38  [As you may have guessed by the title we're go...
# 39  [BOOOOOOOOM!!   https://ninja-narwhal-coffee-c...
# 40  [Â Hey guys so I just uploaded part 1 to YouTu...
# 41  [http://www.youtube.com/watch?v=7AVXCdug1ng&am...
# 42  [Hello to all backers.Â   It's been a while si...
# 43  [You'll need an HTML5 capable browser to see t...
# 44  [Wow, we are half way to meeting our goal! Â H...
# 45  [Well, first thing's first. A little humor.   ...
# 46  [You'll need an HTML5 capable browser to see t...
# 47  [Just a quick note to let you know that early ...
# 48  [Hello our lovely, wonderful backers!   âGee...
# 49  [Hello all,   Spring is here (...in the southe...
# 50  [Faithful backers,  Neurodome took to the podi...
# 51  [You can now order Mr. Meow Plush toys straigh...

# %%
topic_model_animation.get_topic(0)
# Out:
# [('backers', 0.7565515),
#  ('backer', 0.6901392),
#  ('promotion', 0.22582535),
#  ('', 0.1996383),
#  ('', 0.1996383),
#  ('', 0.1996383),
#  ('', 0.1996383),
#  ('', 0.1996383),
#  ('', 0.1996383),
#  ('', 0.1996383)]

# %%
topic_model_animation.visualize_topics()
# Out:
# <div>                            <div id="0c4b5f85-2bab-4616-abf8-bc1128312cea" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c4b5f85-2bab-4616-abf8-bc1128312cea")) {                    Plotly.newPlot(                        "0c4b5f85-2bab-4616-abf8-bc1128312cea",                        [{"customdata":[[0,"backers | backer | promotion |  | ",1509],[1,"pledge | pledges | pledged | pledging | kickstarter",225],[2,"festival | fest | festivals | cinema | cannes",195],[3,"replay | html5 | sound | play | browser",178],[4,"donated | donations | donation | contributions | funding",155],[5," |  |  |  | ",144],[6,"ko |  |  |  | ",141],[7,"film | vimeo | trailer | movie | donated",125],[8,"sky | puppets | film | ghosts | monster",124],[9,"shipping | shipments | shipment | ship | arrive",123],[10,"dai | chuya | shogun | sasahara | samurai",105],[11,"surveys | kickstarter | backerkit | survey | spam",89],[12,"voiced | voice | actor | voices | actors",83],[13,"backers | backer | backings | support | campaign",63],[14,"kickstarter | episodes | episodes\u00e2 | episode | vimeo",63],[15,"musical | soundtrack | music | film | sound",58],[16,"esto | dejamos | como | realidad | gracias",56],[17,"kickstarter | campaign | funding | pledged | funded",54],[18,"ko |  |  |  | ",51],[19,"storyboards | storyboard | animations | animation | animators",49],[20,"replay | html5 | browser | sound | youtube",48],[21,"shirts | shirt | apparel | tee | kickstarter",48],[22,"animation | animated | artwork | characters | designs",47],[23,"kickstarter | funding | campaign | trailer | teaser",46],[24,"morph | morph\u00e2 | merlin | adventures | peter",41],[25,"replay | html5 | browser | sound | play",41],[26,"footage | scenes | animation | frames | film",40],[27,"caretaker | sheriff | mantu | arbutt | ",33],[28,"une | pas | vie | bien | votre",31],[29,"dog\u00e2 | dog\u00e3 | yuri | yuri\u00e3 | dog",31],[30,"kickstarter | kickstartasos | animation | premiered | shows",29],[31,"animate | characters | inspiration\u00e2 | scene | instructor",28],[32,"pledges | pledge | pledged | pledge\u00e2 | rewards",27],[33,"bendito | benditos | todo | kickstarter | zumbakamera",26],[34,"raise | 000 | generous | dollar | dollars",26],[35,"cartoons | cartoon | cartoonist | animation | bunny",24],[36,"cast | movie | characters | jerry | lord",23],[37,"rexfactor | rex | dinosaur | kickstarter | funded",23],[38,"coffeeunicorn | coffee | ninjanarwhalcoffeeco | ninja | mug",21],[39,"video | uploaded | videos | youtube | posted",20],[40,"ifmu8ro_phu | mcsteedinc | youtu | 7avxcdug1ng | youtube",19],[41,"engraving | printed | prints | poster | printing",19],[42,"kickstarter | kickstarttheweirdkidz | kickstarter\u00e3 | kidz | animated",19],[43,"park | indiegogo | studios | film | tale",19],[44,"loved | support | grateful | helping | love",19],[45,"replay | es | spanish | html5 | gracias",18],[46,"dvd | dvds | vimeo | premiere | download",18],[47,"postcards | gifts | rewards | swag | cards",17],[48,"footage | thelittlepainterfilm | animation | animator | film",17],[49,"neuroscience | imaging | cortex | microscope | neurodome",17],[50,"meow | plushies | meowyoga2 | meows | plush",16]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[1509,225,195,178,155,144,141,125,124,123,105,89,83,63,63,58,56,54,51,49,48,48,47,46,41,41,40,33,31,31,29,28,27,26,26,24,23,23,21,20,19,19,19,19,19,18,18,17,17,17,16],"sizemode":"area","sizeref":0.943125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[4.759039402008057,5.382015228271484,4.863784313201904, ...

# %%
topic_model_animation.visualize_barchart(top_n_topics=32)
# Out:
# <div>                            <div id="b428112b-7fd7-499e-ab5c-b339a5a46850" class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b428112b-7fd7-499e-ab5c-b339a5a46850")) {                    Plotly.newPlot(                        "b428112b-7fd7-499e-ab5c-b339a5a46850",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.19963830709457397,0.19963830709457397,0.22582535445690155,0.6901391744613647,0.7565515041351318],"y":["  ","  ","promotion  ","backer  ","backers  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.42668867111206055,0.4451977610588074,0.4897868037223816,0.4946587085723877,0.49675166606903076],"y":["kickstarter  ","pledging  ","pledged  ","pledges  ","pledge  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.4421039819717407,0.4620380401611328,0.5207821130752563,0.5406155586242676,0.5850598812103271],"y":["cannes  ","cinema  ","festivals  ","fest  ","festival  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.3239336609840393,0.34631091356277466,0.3854754567146301,0.399525910615921,0.5153436660766602],"y":["browser  ","play  ","sound  ","html5  ","replay  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.38119953870773315,0.3921159505844116,0.3946976661682129,0.3977651000022888,0.4067002534866333],"y":["funding  ","contributions  ","donation  ","donations  ","donated  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.9776909351348877,0.9776909351348877,0.9776909351348877,0.9776909351348877,0.9776909351348877],"y":["  ","  ","  ","  ","  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.3564671277999878,0.3564671277999878,0.3564671277999878,0.3564671277999878,1.0],"y":["  ","  ","  ","  ","ko  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.3050031065940857,0.3165726363658905,0.35055094957351685,0.3641777038574219,0.391255259513855],"y":["donated  ","movie  ","trailer  ","vimeo  ","film  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.33588308095932007,0.3497231602668762,0.3600538372993469,0.36712491512298584,0.41910767555236816],"y":["monster  ","ghosts  ","film  ","puppets  ","sky  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.37647417187690735,0.4475124478340149,0.4833522439002991,0.4932425916194916,0.5061865448951721],"y":["arrive  ","ship  ","shipment  ","shipments  ","shipping  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.34606069326400757,0.3999467194080353,0.41388434171676636,0.46495670080184937,0.4763997197151184],"y":["samurai  ","sasahara  ","shogun  ","chuya  ","dai  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.35514140129089355,0.36141180992126465,0.3909817337989807,0.486208975315094,0.5159831047058105],"y":["spam  ","survey  ","backerkit  ","kickstarter  ","surveys  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.4369537830352783,0.44890332221984863,0.4840700030326843,0.49651119112968445,0.5350914001464844],"y":["actors  ","voices  ","actor  ","voice  ","voiced  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.31188660860061646,0.32797902822494507,0.4102388620376587,0.46848180890083313,0.47764837741851807],"y":["campaign  ","support  ","backings  ","backer  ","backers  "],"type":"bar","xaxis":"x14"," ...

# %% [markdown]
# ## make a topic model for videogames

# %%
topic_model_videogames = get_standard_bertopic()
topics_videogames, probs_videogames = topic_model_videogames.fit_transform(posts_videogames_projects["Post_Text"])
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
topic_model_videogames.get_topic_info()
# Out:
#      Topic  Count                                           Name  \
# 0       -1  13965          -1_updates_build_progress_kickstarter
# 1        0   3774        0_backers_supporter_kickstarters_trades
# 2        1   1025                                        1_ko___
# 3        2    771              2_reached_foundation_stretch_goal
# 4        3    441        3_soundtracks_instruments_music_musical
# ..     ...    ...                                            ...
# 135    134     16              134_forums_forum_beta_kickstarter
# 136    135     16  135_princess_galactic_galacticprincess_galaxy
# 137    136     16                   136_crashes_alpha_a17_issues
# 138    137     15      137_copies_mastertronic_cassette_releases
# 139    138     15    138_kickstarter_shore_kickstarted_loveshore
#
#                                         Representation  \
# 0    [updates, build, progress, kickstarter, releas...
# 1    [backers, supporter, kickstarters, trades, weâ...
# 2                               [ko, , , , , , , , , ]
# 3    [reached, foundation, stretch, goal, kickstart...
# 4    [soundtracks, instruments, music, musical, mus...
# ..                                                 ...
# 135  [forums, forum, beta, kickstarter, community, ...
# 136  [princess, galactic, galacticprincess, galaxy,...
# 137  [crashes, alpha, a17, issues, bug, 14, build, ...
# 138  [copies, mastertronic, cassette, releases, edi...
# 139  [kickstarter, shore, kickstarted, loveshore, b...
#
#                                    Representative_Docs
# 0    [Alrighty, this is going to be a gigantic upda...
# 1    [ONLY FOR BACKERS, ONLY FOR BACKERS, ONLY FOR ...
# 2                                         [KO, KO, KO]
# 3    [The Final Countdown Begins - 69 Hours remaini...
# 4    [---  1. Tell us about yourself. How did you s...
# ..                                                 ...
# 135  [Greetings, Adventurers!  The dust settled on ...
# 136  [Hi Captains, this is  the recent progress on ...
# 137  [Hey Survivalists, The team has been working h...
# 138  [It's Mastertronic Monday once again and that ...
# 139  [Hello everyone!  We're so excited to share th...
#
# [140 rows x 5 columns]

# %%
topic_model_videogames.get_topic(0)
# Out:
# [('backers', 0.7565515),
#  ('supporter', 0.26904738),
#  ('kickstarters', 0.227015),
#  ('trades', 0.21733657),
#  ('weâ', 0.21639884),
#  ('street', 0.21249054),
#  ('protect', 0.20895839),
#  ('loyal', 0.20319381),
#  ('', 0.19963834),
#  ('', 0.19963834)]

# %%
topic_model_videogames.visualize_topics()
# Out:
# <div>                            <div id="702a9257-e2bf-411f-8a1b-abbef1dbf7fc" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("702a9257-e2bf-411f-8a1b-abbef1dbf7fc")) {                    Plotly.newPlot(                        "702a9257-e2bf-411f-8a1b-abbef1dbf7fc",                        [{"customdata":[[0,"backers | supporter | kickstarters | trades | we\u00e2",3774],[1,"ko |  |  |  | ",1025],[2,"reached | foundation | stretch | goal | kickstarter",771],[3,"soundtracks | instruments | music | musical | musicians",441],[4,"wii | nintendo | consoles | ps4 | playstation",434],[5,"livestream | stream | twitch | streaming | streams",378],[6,"greenlight | greenlit | steam | steamcommunity | kickstarter",341],[7,"keys | steam | key | steampowered | redeem",298],[8,"pax | festival | kickstarter | tickets | seattle",297],[9,"surveys | backerkit | backer | kickstarter | survey",266],[10,"progress | chapters | sprites | characters | artwork",261],[11,"beta | alpha | release | build | testing",251],[12,"overhaul | improvements | starbase | galaxy | fleet",224],[13,"ios | apps | release | android | mobile",210],[14,"replay | html5 | browser | sound | play",209],[15,"vr | oculus | immersivevreducation | virtual | rift",194],[16,"3d | rpg | programming | games | interactive",178],[17,"languages | translations | localize | language | localized",172],[18,"combat | battle | melee | defense | enemy",136],[19,"shipments | shipping | shipment | ship | delivery",126],[20,"kickstarter | paypal | pledged | payment | payments",118],[21," |  |  |  | ",108],[22,"pledge | pledges | pledged | pledging | campaign",99],[23,"mac | macos | osx | macs | os",96],[24,"christmas | xmas | merry | holiday | holidays",95],[25,"hardcover | artbook | booklet | artwork | pages",93],[26,"voice | voiced | voices | voicing | audition",92],[27,"shirts | shirt | tshirt | logo | tee",86],[28,"steam | release | released | steampowered | steamcommunity",85],[29,"une | votre | plusieurs | \u00e3\u00aatre | pas",78],[30,"sins | sinners | slayers | sin | demonking",77],[31,"progress | build | making | animations | cutscenes",77],[32,"cattailsgame | cattails | catamancer | cat | catamancers",75],[33,"dans | les | bien | des | pas",65],[34,"pledged | pledge | pledges | kickstarter | extra",62],[35,"rpg | kickstarter | terrain | campaign | playable",59],[36,"landmark | landmarks | moguls | buildings | towers",59],[37,"sleep | progress | schedule | work | patience",58],[38,"sunless | skyfarer | sunrider | sky | skyfarers",56],[39,"gaymerx | gaymerx2 | gaymercon | gx4 | gx",55],[40,"trailer | trailers | cinematic | teaser | launch",54],[41," |  |  |  | ",52],[42,"luna | luna\u00e2 | lunar | moonquest | moon",52],[43,"nesmaker | nes | kickstarter | flasher | flashers",52],[44,"kickstarter | novels | characters | novel | designs",50],[45,"release | releasing | date | patience | updates",50],[46,"jupiter | chaosforge | kickstarter | planet | planets",48],[47,"nova | novablitzgame | blitz | novablitz | rewards",47],[48,"terraforming | forest | trees | building | prehistoric",45],[49,"paradise_lost_fps_cosmic_horror_game | release | released | releasing | demo",44],[50,"catfish | fish | fishcat | fishing | reel",43],[51,"aleena | goddess | venusblood | celeste | valana",43],[52,"drawandrace | drawandrace2 | drawandrace3 | drawandrace5 | drawandrace4",41],[53,"replay | html5 | browser | sound | play",41],[54,"levels | level | stages | 3d | stage",40],[55,"dragonfinsoup | dragon | dragon\u00e2 | soup | dragons",40],[56,"improvements | updates | changes | updated | improved",40],[57,"release | cosmochoria | launch | steam | update",40],[58,"contest | fanart | submissions | winners | prizes",38],[59,"foxnforests | forests | foxnforestsgame | foxnforestsga ...

# %%
topic_model_videogames.visualize_barchart(top_n_topics=32)
# Out:
# <div>                            <div id="5e2cc46c-5711-4eba-9536-a4f86c880998" class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e2cc46c-5711-4eba-9536-a4f86c880998")) {                    Plotly.newPlot(                        "5e2cc46c-5711-4eba-9536-a4f86c880998",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.21639883518218994,0.21733656525611877,0.22701500356197357,0.2690473794937134,0.7565515041351318],"y":["we\u00e2  ","trades  ","kickstarters  ","supporter  ","backers  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.3564671277999878,0.3564671277999878,0.3564671277999878,0.3564671277999878,1.0],"y":["  ","  ","  ","  ","ko  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.3424322009086609,0.3515375852584839,0.3523252010345459,0.3540598154067993,0.3819829225540161],"y":["kickstarter  ","goal  ","stretch  ","foundation  ","reached  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.4764106869697571,0.5001465082168579,0.5015020370483398,0.5033326148986816,0.5569391846656799],"y":["musicians  ","musical  ","music  ","instruments  ","soundtracks  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.3382343053817749,0.35471296310424805,0.35641980171203613,0.43523645401000977,0.4512501060962677],"y":["playstation  ","ps4  ","consoles  ","nintendo  ","wii  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.43817317485809326,0.4719392657279968,0.5228287577629089,0.536949098110199,0.5735000371932983],"y":["streams  ","streaming  ","twitch  ","stream  ","livestream  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.3261914849281311,0.40777188539505005,0.4533160328865051,0.5424457788467407,0.6013106107711792],"y":["kickstarter  ","steamcommunity  ","steam  ","greenlit  ","greenlight  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.33485937118530273,0.35739564895629883,0.41516488790512085,0.43748509883880615,0.445315420627594],"y":["redeem  ","steampowered  ","key  ","steam  ","keys  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.3110772371292114,0.317271888256073,0.31958383321762085,0.3588365912437439,0.47686588764190674],"y":["seattle  ","tickets  ","kickstarter  ","festival  ","pax  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.368028461933136,0.3886328935623169,0.39506450295448303,0.49885714054107666,0.5286807417869568],"y":["survey  ","kickstarter  ","backer  ","backerkit  ","surveys  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.30243679881095886,0.31667348742485046,0.32565152645111084,0.3298388719558716,0.4221448600292206],"y":["artwork  ","characters  ","sprites  ","chapters  ","progress  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.32992878556251526,0.33720308542251587,0.3696657419204712,0.48926931619644165,0.5013920068740845],"y":["testing  ","build  ","release  ","alpha  ","beta  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.3419479727745056,0.34769171476364136,0.3663542568683624,0.39666855335235596,0.40756821632385254],"y":["fleet  ","galaxy  ","starbase  ","improvements  ","overhaul  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.4313078224658966,0.43537843227386475,0.44063013792037964,0.44288790225982666,0.558 ...
